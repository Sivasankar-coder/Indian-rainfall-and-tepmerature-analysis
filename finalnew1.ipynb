# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
import numpy as np

path = "C:/Users/Siva/Desktop/New folder (2)/archive_2/rainfall in india 1901-2015.csv"
tempdata = pd.read_csv("C:/Users/Siva/Desktop/New folder (2)/New folder (2)/GlobalLandTemperaturesByMajorCity.csv",
                       parse_dates=["dt"])
data = pd.read_csv(path)

tempdata.isna().sum()

tempdata.isna().sum() / data.shape[0] * 100

tempdata.dropna(inplace=True)

tempdata.isna().sum()

tempdata.head()

tempdata[["City", "Country"]]

tempdata["Country"].value_counts()

tempdata[(tempdata["Country"]=="Mumbai") | (tempdata["Country"]=="Delhi")]

tempdata[(tempdata["Country"]=="Mumbai") & (tempdata["AverageTemperature"] > 20)]

tempdata_selected = tempdata[tempdata["Country"].isin(["Mumbai", "Delhi", "Tamilnadu"])]

tempdata_selected.head()

tempdata_selected.groupby(by="Country").mean()

tempdata_selected.groupby(by="Country").agg(["min", "max", "mean"])
tr_avg_temps = tempdata_selected[tempdata_selected["Country"]=="Mumbai"]["AverageTemperature"]
br_avg_temps = tempdata_selected[tempdata_selected["Country"]=="Delhi"]["AverageTemperature"]
us_avg_temps = tempdata_selected[tempdata_selected["Country"]=="Tamilnadu"]["AverageTemperature"]

sns.distplot(tr_avg_temps)
sns.distplot(us_avg_temps)
sns.distplot(br_avg_temps)

tempdata_selected["Country"].value_counts().index

cdata = tempdata_selected["Country"].unique()

# Getting rainfall data for Tamilnadu
Tamilnadu = data.loc[((data['SUBDIVISION'] == 'TAMIL NADU'))]
Delhi = data.loc[(data['SUBDIVISION'] == 'DELHI')]
Mumbai = data.loc[(data['SUBDIVISION'] == 'MUMBAI')]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
    inp1 = input("please Enter 'Yearly' or 'Monthly' ")
    inp1.lower()
    inp2 = input("What type of data you want about the Weather - 'Rain' or 'Temperature' ")
    inp2.lower()
    inp3 = input("What Type of Graph you Want - 'Line' or 'Barchart' ")
    inp3.lower()
    if inp1 == "year" or inp1 == "yearly":
        if inp2 == "rain" or inp2 == "rainfall":
            if inp3 == "bar" or inp3 == "barchart":

                data[['SUBDIVISION', 'ANNUAL']].sort_values(by='ANNUAL', ascending=False).head(20)



                # Average monthly rainfall in India
                ax = data[['Jan-Feb', 'Mar-May', 'Jun-Sep', 'Oct-Dec']].mean().plot.bar(width=0.5, linewidth=2,
                                                                                        figsize=(16, 10))
                plt.xlabel('Quarter', fontsize=15)
                plt.ylabel('Quarterly Rainfall (in mm)', fontsize=15)
                plt.title('Quarterly Rainfall in India', fontsize=20)
                plt.legend(['Subdivisions'])
                ax.tick_params(labelsize=15)
                plt.grid()
                plt.show()



                # Getting rainfall data for Tamilnadu
                Tamilnadu = data.loc[((data['SUBDIVISION'] == 'TAMIL NADU'))]



                # Average monthly rainfall in Tamilnadu
                TM = Tamilnadu[['Jan-Feb', 'Mar-May', 'Jun-Sep', 'Oct-Dec']].mean().plot.bar(width=0.5, linewidth=2,
                                                                                             figsize=(16, 10),
                                                                                             color='lightgreen')
                plt.xlabel('Quarter', fontsize=15)
                plt.ylabel('Quarterly Rainfall (in mm)', fontsize=15)
                plt.title('Quarterly Rainfall in Tamilnadu', fontsize=20)
                plt.legend(['Tamilnadu'])
                TM.tick_params(labelsize=15)
                plt.grid()
                plt.show()



                print('Average annual rainfall received by Tamilnadu = ', int(Tamilnadu['ANNUAL'].mean()), 'mm')
                a = Tamilnadu[Tamilnadu['YEAR'] == 1917]

                # Getting rainfall data for Delhi
                Delhi = data.loc[(data['SUBDIVISION'] == 'DELHI')]



                # Average monthly rainfall in Arunachal Pradesh
                DM = Delhi[['Jan-Feb', 'Mar-May', 'Jun-Sep', 'Oct-Dec']].mean().plot.bar(width=0.5, linewidth=2,
                                                                                         figsize=(16, 10),
                                                                                         color="violet")
                plt.xlabel('Quarter', fontsize=15)
                plt.ylabel('Quarterly Rainfall (in mm)', fontsize=15)
                plt.title('Quarterly Rainfall in Delhi', fontsize=20)
                plt.legend(['Delhi'])
                DM.tick_params(labelsize=15)
                plt.grid()
                plt.show()



                print('Average annual rainfall received by Arunachal Pradesh = ', int(Delhi['ANNUAL'].mean()), 'mm')
                a = Delhi[Delhi['YEAR'] == 1948]

                # Getting rainfall data for Mumbai
                Mumbai = data.loc[(data['SUBDIVISION'] == 'MUMBAI')]



                # Average monthly rainfall in mumbai
                MM = Mumbai[['Jan-Feb', 'Mar-May', 'Jun-Sep', 'Oct-Dec']].mean().plot.bar(width=0.5, linewidth=2,
                                                                                          figsize=(16, 10),
                                                                                          color="orange")
                plt.xlabel('Quarter', fontsize=15)
                plt.ylabel('Quarterly Rainfall (in mm)', fontsize=15)
                plt.title('Quarterly Rainfall in Mumbai', fontsize=20)
                plt.legend(['Mumbai'])
                MM.tick_params(labelsize=15)
                plt.grid()
                plt.show()



                # Average monthly rainfall in t,M,D

                DM = Delhi[['Jan-Feb', 'Mar-May', 'Jun-Sep', 'Oct-Dec']].mean()

                TM = Tamilnadu[['Jan-Feb', 'Mar-May', 'Jun-Sep', 'Oct-Dec']].mean()
                MM = Mumbai[['Jan-Feb', 'Mar-May', 'Jun-Sep', 'Oct-Dec']].mean()

                plt.subplots(figsize=(16, 10))
                plt.xlabel('Quarter', fontsize=15)
                plt.ylabel('Quarterly Rainfall (in mm)', fontsize=15)
                plt.title('Quarterly Rainfall in Tamilnadu,Delhi and Mumbai', fontsize=20)
                X = np.arange(4)
                bar1 = plt.bar(X + 0.00, TM, color='lightgreen', width=0.25)
                bar2 = plt.bar(X + 0.25, DM, color='violet', width=0.25)
                bar3 = plt.bar(X + 0.50, MM, color='orange', width=0.25)

                plt.legend((bar1, bar2, bar3), ('Tamilnadu', 'Delhi', 'Mumbai'))
                plt.grid()
                plt.xticks(X + 0.25, ['Jan-Feb', 'Mar-May', 'Jun-Sep', 'Oct-Dec'])
                plt.show()




            else:
                
                # Visualizing annual rainfall over the years(1901-2015) in India
                ax = data.groupby("YEAR").mean()['ANNUAL'].plot(ylim=(1000, 2000), color='r', marker='o', linestyle='-',linewidth=2, figsize=(12, 10));
                plt.xlabel('Year', fontsize=20)
                plt.ylabel('Annual Rainfall (in mm)', fontsize=20)
                plt.title('Annual Rainfall from Year 1901 to 2015 in India', fontsize=25)
                plt.legend(['India'])
                ax.tick_params(labelsize=15)
                plt.grid()
                plt.show()
                

                # Visualizing annual rainfall over the years(1901-2015) in Tamilnadu
                TY = Tamilnadu.groupby("YEAR").mean()['ANNUAL'].plot(ylim=(50, 1500), color='green', marker='o',
                                                                     linestyle='-', linewidth=2, figsize=(12, 10));
                plt.xlabel('Year', fontsize=20)
                plt.ylabel('Tamilnadu Annual Rainfall (in mm)', fontsize=20)
                plt.title('Tamilnadu Annual Rainfall from Year 1901 to 2015', fontsize=25)
                plt.legend(['Tamilnadu'])
                TY.tick_params(labelsize=15)
                plt.grid()
                plt.show()

                # Visualizing annual rainfall over the years(1901-2015) in delhi
                DY = Delhi.groupby("YEAR").mean()['ANNUAL'].plot(ylim=(50, 6500), color='violet', marker='o',
                                                                 linestyle='-', linewidth=2, figsize=(12, 10));
                plt.xlabel('Year', fontsize=20)
                plt.ylabel('Delhi Annual Rainfall (in mm)', fontsize=20)
                plt.title('Delhi Annual Rainfall from Year 1901 to 2015', fontsize=25)
                plt.legend(['Delhi'])
                DY.tick_params(labelsize=15)
                plt.grid()
                plt.show()

                # Visualizing annual rainfall over the years(1901-2015) in mumbai
                MY = Mumbai.groupby("YEAR").mean()['ANNUAL'].plot(ylim=(1500, 6500), color='orange', marker='o',
                                                                  linestyle='-', linewidth=2, figsize=(12, 10));
                plt.xlabel('Year', fontsize=20)
                plt.ylabel('Mumbai Annual Rainfall (in mm)', fontsize=20)
                plt.title('Mumbai Annual Rainfall from Year 1901 to 2015', fontsize=25)
                plt.legend(['Mumbai'])
                ax.tick_params(labelsize=15)
                plt.grid()
                plt.show()

                # Visualizing annual rainfall over the years(1901-2015) in t,m,d
                TY = Tamilnadu.groupby("YEAR").mean()['ANNUAL'].plot(ylim=(50, 7000), color='green', marker='o',
                                                                     linestyle='-', linewidth=2, figsize=(12, 10));
                DY = Delhi.groupby("YEAR").mean()['ANNUAL'].plot(ylim=(50, 7000), color='violet', marker='o',
                                                                 linestyle='-', linewidth=2, figsize=(12, 10));

                MY = Mumbai.groupby("YEAR").mean()['ANNUAL'].plot(ylim=(50, 7000), color='orange', marker='o',
                                                                  linestyle='-', linewidth=2, figsize=(12, 10));
                plt.xlabel('Year', fontsize=20)
                plt.ylabel('T,D,and M Annual Rainfall (in mm)', fontsize=20)
                plt.title(' T,D,and M Annual Rainfall from Year 1901 to 2015', fontsize=25)
                plt.legend(['Tamilnadu', 'Delhi', 'Mumbai'])
                TY.tick_params(labelsize=15)
                DY.tick_params(labelsize=15)
                MY.tick_params(labelsize=15)
                plt.grid()
                plt.show()
                
                 # Visualizing annual rainfall over the years(1901-2015) in India
                ax = data.groupby("YEAR").mean()['ANNUAL'].plot(ylim=(1000, 2000), color='r', linestyle='-',linewidth=2, figsize=(12, 10));
                plt.xlabel('Year', fontsize=20)
                plt.ylabel('Annual Rainfall (in mm)', fontsize=20)
                plt.title('Annual Rainfall from Year 1901 to 2015 in India', fontsize=25)
                plt.legend(['India'])
                ax.tick_params(labelsize=15)
                plt.grid()
                plt.show()
                

                # Visualizing annual rainfall over the years(1901-2015) in Tamilnadu
                TY = Tamilnadu.groupby("YEAR").mean()['ANNUAL'].plot(ylim=(50, 1500), color='green',
                                                                     linestyle='-', linewidth=2, figsize=(12, 10));
                plt.xlabel('Year', fontsize=20)
                plt.ylabel('Tamilnadu Annual Rainfall (in mm)', fontsize=20)
                plt.title('Tamilnadu Annual Rainfall from Year 1901 to 2015', fontsize=25)
                plt.legend(['Tamilnadu'])
                TY.tick_params(labelsize=15)
                plt.grid()
                plt.show()

                # Visualizing annual rainfall over the years(1901-2015) in delhi
                DY = Delhi.groupby("YEAR").mean()['ANNUAL'].plot(ylim=(50, 6500), color='violet',
                                                                 linestyle='-', linewidth=2, figsize=(12, 10));
                plt.xlabel('Year', fontsize=20)
                plt.ylabel('Delhi Annual Rainfall (in mm)', fontsize=20)
                plt.title('Delhi Annual Rainfall from Year 1901 to 2015', fontsize=25)
                plt.legend(['Delhi'])
                DY.tick_params(labelsize=15)
                plt.grid()
                plt.show()

                # Visualizing annual rainfall over the years(1901-2015) in mumbai
                MY = Mumbai.groupby("YEAR").mean()['ANNUAL'].plot(ylim=(1500, 6500), color='orange',
                                                                  linestyle='-', linewidth=2, figsize=(12, 10));
                plt.xlabel('Year', fontsize=20)
                plt.ylabel('Mumbai Annual Rainfall (in mm)', fontsize=20)
                plt.title('Mumbai Annual Rainfall from Year 1901 to 2015', fontsize=25)
                plt.legend(['Mumbai'])
                ax.tick_params(labelsize=15)
                plt.grid()
                plt.show()

                # Visualizing annual rainfall over the years(1901-2015) in t,d,m
                TY = Tamilnadu.groupby("YEAR").mean()['ANNUAL'].plot(ylim=(50, 7000), color='green',
                                                                     linestyle='-', linewidth=2, figsize=(12, 10));
                DY = Delhi.groupby("YEAR").mean()['ANNUAL'].plot(ylim=(50, 7000), color='violet',
                                                                 linestyle='-', linewidth=2, figsize=(12, 10));

                MY = Mumbai.groupby("YEAR").mean()['ANNUAL'].plot(ylim=(50, 7000), color='orange',
                                                                  linestyle='-', linewidth=2, figsize=(12, 10));
                plt.xlabel('Year', fontsize=20)
                plt.ylabel('T,D,and M Annual Rainfall (in mm)', fontsize=20)
                plt.title('T,D,and M Annual Rainfall from Year 1901 to 2015', fontsize=25)
                plt.legend(['Tamilnadu', 'Delhi', 'Mumbai'])
                TY.tick_params(labelsize=15)
                DY.tick_params(labelsize=15)
                MY.tick_params(labelsize=15)
                plt.grid()
                plt.show()
                
                tempdata_selected = data[data["SUBDIVISION"].isin(["MUMBAI", "DELHI", "TAMIL NADU"])]
                tr_avg_temps = tempdata_selected[tempdata_selected["SUBDIVISION"]=="MUMBAI"]["ANNUAL"]
                br_avg_temps = tempdata_selected[tempdata_selected["SUBDIVISION"]=="DELHI"]["ANNUAL"]
                us_avg_temps = tempdata_selected[tempdata_selected["SUBDIVISION"]=="TAMIL NADU"]["ANNUAL"]
                plt.xlabel('Year', fontsize=10)
                plt.ylabel('T,D,and M Annual Rainfall (in mm)', fontsize=10)
                plt.title('T,D,and M Annual Rainfall from Year 1901 to 2015', fontsize=10)
                plt.legend(['Tamilnadu', 'Delhi', 'Mumbai'])
                sns.distplot(tr_avg_temps)
                sns.distplot(us_avg_temps)
                sns.distplot(br_avg_temps)
                plt.legend(['Tamilnadu', 'Delhi', 'Mumbai'])
                plt.show()

        elif inp2 == "temp" or inp2 == "temperature":
            if inp3 == "bar" or inp3 == "barchar":
                T = tempdata_selected[tempdata_selected["Country"] == cdata[2]]["AverageTemperature"]
                D = tempdata_selected[tempdata_selected["Country"] == cdata[1]]["AverageTemperature"]
                M = tempdata_selected[tempdata_selected["Country"] == cdata[0]]["AverageTemperature"]

                plt.subplots(figsize=(16, 10))
                plt.xlabel('Quarter', fontsize=15)
                plt.ylabel('Quarterly Rainfall (in mm)', fontsize=15)
                plt.title('Quarterly Rainfall in Tamilnadu,Delhi and Mumbai', fontsize=20)
                X = np.arange(6)
                bar1 = plt.bar(0.00, T, color='g', width=0.25)
                bar2 = plt.bar(0.25, D, color='b', width=0.25)
                bar3 = plt.bar(0.50, M, color='orange', width=0.25)

                plt.legend((bar1, bar2, bar3), ('Tamilnadu', 'Delhi', 'Mumbai'))
                plt.grid()
                # plt.xticks(X+0.25,['1900','1920','1940','1960','1980','2000'])
                plt.show()
            else:
                sns.distplot(tr_avg_temps)
                sns.distplot(us_avg_temps)
                sns.distplot(br_avg_temps)

                cdata = tempdata_selected["Country"].unique()
                for c in cdata:
                    sns.distplot(tempdata_selected[tempdata_selected["Country"] == c]["AverageTemperature"])

                sns.set_style("whitegrid")
                plt.legend(['Mumbai','Delhi','Tamilnadu'])
                plt.figure(figsize=(15, 5))

                for c in cdata:
                    sns.distplot(tempdata_selected[tempdata_selected["Country"] == c]["AverageTemperature"])

                plt.legend(cdata)

                sns.set_style("whitegrid")
                plt.figure(figsize=(15, 5))
                color = ["green", "blue", "orange"]

                for color, c in zip(color, cdata):
                    sns.distplot(tempdata_selected[tempdata_selected["Country"] == c]["AverageTemperature"])
                    cmean = tempdata_selected[tempdata_selected["Country"] == c]["AverageTemperature"].mean()
                    plt.vlines(cmean, 0, 0.16, color=color)

                plt.legend(cdata)

                tempdata_selected.columns[1:3]

                colv = tempdata_selected.columns[1:3]
                cdata = tempdata_selected["Country"].unique()
                plt.figure(figsize=(15, 5))

                for col in colv:
                    plt.figure(figsize=(15, 5))
                    for c in cdata:
                        sns.distplot(tempdata_selected[tempdata_selected["Country"] == c][col])
                    plt.legend(['Mumbai','Delhi','Tamilnadu'])
                    plt.show()

                trData = tempdata_selected[(tempdata_selected["Country"] == "Mumbai") & (tempdata_selected["dt"] > "01.01.1900")]
                

                trData_mean = trData.groupby(trData["dt"].dt.to_period("Y")).mean()
                trData_mean = trData_mean.reset_index()
                
                trData_mean["dt"] = trData_mean["dt"].astype("string").astype("datetime64")
                plt.figure(figsize=(15, 5))

                sns.lineplot(x="dt", y="AverageTemperature", data=trData_mean,color='b')
                plt.legend(['Mumbai'])
                
                trData = tempdata_selected[(tempdata_selected["Country"] == "Delhi") & (tempdata_selected["dt"] > "01.01.1900")]
                

                trData_mean = trData.groupby(trData["dt"].dt.to_period("Y")).mean()
                trData_mean = trData_mean.reset_index()
                
                trData_mean["dt"] = trData_mean["dt"].astype("string").astype("datetime64")
                plt.figure(figsize=(15, 5))

                sns.lineplot(x="dt", y="AverageTemperature", data=trData_mean,color='orange')
                plt.legend(['Delhi'])
                
                trData = tempdata_selected[(tempdata_selected["Country"] == "Tamilnadu") & (tempdata_selected["dt"] > "01.01.1900")]
                

                trData_mean = trData.groupby(trData["dt"].dt.to_period("Y")).mean()
                trData_mean = trData_mean.reset_index()
                
                trData_mean["dt"] = trData_mean["dt"].astype("string").astype("datetime64")
                plt.figure(figsize=(15, 5))

                sns.lineplot(x="dt", y="AverageTemperature", data=trData_mean,color='g')
                plt.legend(['Tamilnadu'])
                
                data_1900 = tempdata_selected[tempdata_selected["dt"] > "01.01.1900"]
                
                data_means = data_1900.groupby(["Country", data_1900["dt"].dt.to_period("Y")]).mean()
                data_means = data_means.reset_index()
                data_means["dt"] = data_means["dt"].astype("string").astype("datetime64")
                
                for column in data_means.columns[2:4]:
                    plt.figure(figsize=(15, 5))

                    for c in data_means["Country"].unique():
                        data = data_means[data_means["Country"] == c]
                        sns.lineplot(x="dt", y=col, data=data)
                    plt.legend(['Mumbai','Delhi','Tamilnadu'])

    elif inp1 == "month" or inp1 == "monthly":

        if inp2 == "rain" or inp2 == "rainfall":

            if inp3 == "bar" or inp3 == "barchart":
                # Average monthly rainfall in India
                ax = data[['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC']].mean()
                plt.subplots(figsize=(16, 10))
                plt.xlabel('Month', fontsize=30)
                plt.ylabel('Monthly Rainfall (in mm)', fontsize=30)
                plt.title('Monthly Rainfall in Subdivisions of India', fontsize=25)
                
               
                X = np.arange(11)
                bar1 = plt.bar(X + 0.00, ax, color='b', width=0.25)
                plt.legend(['Subdivisions'])
                plt.grid()
                plt.xticks(X + 0.25, ['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC'])
                plt.show()

                # Average monthly rainfall in Tamilnadu
                T = Tamilnadu[['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC']].mean()
                plt.subplots(figsize=(16, 10))
                plt.xlabel('Month', fontsize=30)
                plt.ylabel('Monthly Rainfall (in mm)', fontsize=30)
                plt.title('Monthly Rainfall in Tamilnadu', fontsize=25)
                
                X = np.arange(11)
                plt.bar(X + 0.00, T, color='lightgreen', width=0.25)
                

                plt.legend(['Tamilnadu'])
                plt.grid()
                plt.xticks(X + 0.25, ['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC'])
                plt.show()

                # Average monthly rainfall in Delhi
                D = Delhi[['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC']].mean()
                plt.subplots(figsize=(16, 10))
                plt.xlabel('Month', fontsize=30)
                plt.ylabel('Monthly Rainfall (in mm)', fontsize=30)
                plt.title('Monthly Rainfall in Delhi', fontsize=25)
                
                X = np.arange(11)
                
                bar2 = plt.bar(X + 0.25, D, color='violet', width=0.25)
                

                plt.legend(['Delhi'])
                plt.grid()
                plt.xticks(X + 0.25, ['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC'])
                plt.show()
                
                

                # Average monthly rainfall in Mumbai
                M = Mumbai[['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC']].mean()
                plt.subplots(figsize=(16, 10))
                plt.xlabel('Month', fontsize=30)
                plt.ylabel('Monthly Rainfall (in mm)', fontsize=30)
                plt.title('Monthly Rainfall in Mumbai', fontsize=25)
                
                X = np.arange(11)
                
                bar3 = plt.bar(X + 0.50, M, color='orange', width=0.25)

                plt.legend(['Mumbai'])
                plt.grid()
                plt.xticks(X + 0.25, ['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC'])
                plt.show()


                # Average monthly rainfall in Tamilnadu
                T = Tamilnadu[['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC']].mean()

                D = Delhi[['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC']].mean()

                M = Mumbai[['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC']].mean()

                plt.subplots(figsize=(16, 10))
                plt.xlabel('Quarter', fontsize=15)
                plt.ylabel('Quarterly Rainfall (in mm)', fontsize=15)
                plt.title('Quarterly Rainfall in Tamilnadu,Delhi and Mumbai', fontsize=20)
                X = np.arange(11)
                bar1 = plt.bar(X + 0.00, T, color='lightgreen', width=0.25)
                bar2 = plt.bar(X + 0.25, D, color='violet', width=0.25)
                bar3 = plt.bar(X + 0.50, M, color='orange', width=0.25)

                plt.legend((bar1, bar2, bar3), ('Tamilnadu', 'Delhi', 'Mumbai'))
                plt.grid()
                plt.xticks(X + 0.25, ['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC'])
                plt.show()
            else:
                print("No Data Found")
        elif inp2 == "temp" or inp2 == "temperature":
            if inp3 == "bar" or inp3 == "barchar":
                print("No Data Found")
            else:
                print("No Data Found")
# Out:
# please Enter 'Yearly' or 'Monthly' year
# What type of data you want about the Weather - 'Rain' or 'Temperature' temp
# What Type of Graph you Want - 'Line' or 'Barchart' bar

# %%
    inp1 = input("please Enter 'Yearly' or 'Monthly' ")
    inp1.lower()
    inp2 = input("What type of data you want about the Weather - 'Rain' or 'Temperature' ")
    inp2.lower()
    inp3 = input("What Type of Graph you Want - 'Line' or 'Barchart' ")
    inp3.lower()
    if inp1 == "year" or inp1 == "yearly":
        if inp2 == "rain" or inp2 == "rainfall":
            if inp3 == "bar" or inp3 == "barchart":

                data[['SUBDIVISION', 'ANNUAL']].sort_values(by='ANNUAL', ascending=False).head(20)



                # Average monthly rainfall in India
                ax = data[['Jan-Feb', 'Mar-May', 'Jun-Sep', 'Oct-Dec']].mean().plot.bar(width=0.5, linewidth=2,
                                                                                        figsize=(16, 10))
                plt.xlabel('Quarter', fontsize=15)
                plt.ylabel('Quarterly Rainfall (in mm)', fontsize=15)
                plt.title('Quarterly Rainfall in India', fontsize=20)
                plt.legend(['Subdivisions'])
                ax.tick_params(labelsize=15)
                plt.grid()
                plt.show()



                # Getting rainfall data for Tamilnadu
                Tamilnadu = data.loc[((data['SUBDIVISION'] == 'TAMIL NADU'))]



                # Average monthly rainfall in Tamilnadu
                TM = Tamilnadu[['Jan-Feb', 'Mar-May', 'Jun-Sep', 'Oct-Dec']].mean().plot.bar(width=0.5, linewidth=2,
                                                                                             figsize=(16, 10),
                                                                                             color='lightgreen')
                plt.xlabel('Quarter', fontsize=15)
                plt.ylabel('Quarterly Rainfall (in mm)', fontsize=15)
                plt.title('Quarterly Rainfall in Tamilnadu', fontsize=20)
                plt.legend(['Tamilnadu'])
                TM.tick_params(labelsize=15)
                plt.grid()
                plt.show()



                print('Average annual rainfall received by Tamilnadu = ', int(Tamilnadu['ANNUAL'].mean()), 'mm')
                a = Tamilnadu[Tamilnadu['YEAR'] == 1917]

                # Getting rainfall data for Delhi
                Delhi = data.loc[(data['SUBDIVISION'] == 'DELHI')]



                # Average monthly rainfall in Arunachal Pradesh
                DM = Delhi[['Jan-Feb', 'Mar-May', 'Jun-Sep', 'Oct-Dec']].mean().plot.bar(width=0.5, linewidth=2,
                                                                                         figsize=(16, 10),
                                                                                         color="violet")
                plt.xlabel('Quarter', fontsize=15)
                plt.ylabel('Quarterly Rainfall (in mm)', fontsize=15)
                plt.title('Quarterly Rainfall in Delhi', fontsize=20)
                plt.legend(['Delhi'])
                DM.tick_params(labelsize=15)
                plt.grid()
                plt.show()



                print('Average annual rainfall received by Arunachal Pradesh = ', int(Delhi['ANNUAL'].mean()), 'mm')
                a = Delhi[Delhi['YEAR'] == 1948]

                # Getting rainfall data for Mumbai
                Mumbai = data.loc[(data['SUBDIVISION'] == 'MUMBAI')]



                # Average monthly rainfall in mumbai
                MM = Mumbai[['Jan-Feb', 'Mar-May', 'Jun-Sep', 'Oct-Dec']].mean().plot.bar(width=0.5, linewidth=2,
                                                                                          figsize=(16, 10),
                                                                                          color="orange")
                plt.xlabel('Quarter', fontsize=15)
                plt.ylabel('Quarterly Rainfall (in mm)', fontsize=15)
                plt.title('Quarterly Rainfall in Mumbai', fontsize=20)
                plt.legend(['Mumbai'])
                MM.tick_params(labelsize=15)
                plt.grid()
                plt.show()



                # Average monthly rainfall in t,M,D

                DM = Delhi[['Jan-Feb', 'Mar-May', 'Jun-Sep', 'Oct-Dec']].mean()

                TM = Tamilnadu[['Jan-Feb', 'Mar-May', 'Jun-Sep', 'Oct-Dec']].mean()
                MM = Mumbai[['Jan-Feb', 'Mar-May', 'Jun-Sep', 'Oct-Dec']].mean()

                plt.subplots(figsize=(16, 10))
                plt.xlabel('Quarter', fontsize=15)
                plt.ylabel('Quarterly Rainfall (in mm)', fontsize=15)
                plt.title('Quarterly Rainfall in Tamilnadu,Delhi and Mumbai', fontsize=20)
                X = np.arange(4)
                bar1 = plt.bar(X + 0.00, TM, color='lightgreen', width=0.25)
                bar2 = plt.bar(X + 0.25, DM, color='violet', width=0.25)
                bar3 = plt.bar(X + 0.50, MM, color='orange', width=0.25)

                plt.legend((bar1, bar2, bar3), ('Tamilnadu', 'Delhi', 'Mumbai'))
                plt.grid()
                plt.xticks(X + 0.25, ['Jan-Feb', 'Mar-May', 'Jun-Sep', 'Oct-Dec'])
                plt.show()




            else:
                
                # Visualizing annual rainfall over the years(1901-2015) in India
                ax = data.groupby("YEAR").mean()['ANNUAL'].plot(ylim=(1000, 2000), color='r', marker='o', linestyle='-',linewidth=2, figsize=(12, 10));
                plt.xlabel('Year', fontsize=20)
                plt.ylabel('Annual Rainfall (in mm)', fontsize=20)
                plt.title('Annual Rainfall from Year 1901 to 2015 in India', fontsize=25)
                plt.legend(['India'])
                ax.tick_params(labelsize=15)
                plt.grid()
                plt.show()
                

                # Visualizing annual rainfall over the years(1901-2015) in Tamilnadu
                TY = Tamilnadu.groupby("YEAR").mean()['ANNUAL'].plot(ylim=(50, 1500), color='green', marker='o',
                                                                     linestyle='-', linewidth=2, figsize=(12, 10));
                plt.xlabel('Year', fontsize=20)
                plt.ylabel('Tamilnadu Annual Rainfall (in mm)', fontsize=20)
                plt.title('Tamilnadu Annual Rainfall from Year 1901 to 2015', fontsize=25)
                plt.legend(['Tamilnadu'])
                TY.tick_params(labelsize=15)
                plt.grid()
                plt.show()

                # Visualizing annual rainfall over the years(1901-2015) in delhi
                DY = Delhi.groupby("YEAR").mean()['ANNUAL'].plot(ylim=(50, 6500), color='violet', marker='o',
                                                                 linestyle='-', linewidth=2, figsize=(12, 10));
                plt.xlabel('Year', fontsize=20)
                plt.ylabel('Delhi Annual Rainfall (in mm)', fontsize=20)
                plt.title('Delhi Annual Rainfall from Year 1901 to 2015', fontsize=25)
                plt.legend(['Delhi'])
                DY.tick_params(labelsize=15)
                plt.grid()
                plt.show()

                # Visualizing annual rainfall over the years(1901-2015) in mumbai
                MY = Mumbai.groupby("YEAR").mean()['ANNUAL'].plot(ylim=(1500, 6500), color='orange', marker='o',
                                                                  linestyle='-', linewidth=2, figsize=(12, 10));
                plt.xlabel('Year', fontsize=20)
                plt.ylabel('Mumbai Annual Rainfall (in mm)', fontsize=20)
                plt.title('Mumbai Annual Rainfall from Year 1901 to 2015', fontsize=25)
                plt.legend(['Mumbai'])
                ax.tick_params(labelsize=15)
                plt.grid()
                plt.show()

                # Visualizing annual rainfall over the years(1901-2015) in t,m,d
                TY = Tamilnadu.groupby("YEAR").mean()['ANNUAL'].plot(ylim=(50, 7000), color='green', marker='o',
                                                                     linestyle='-', linewidth=2, figsize=(12, 10));
                DY = Delhi.groupby("YEAR").mean()['ANNUAL'].plot(ylim=(50, 7000), color='violet', marker='o',
                                                                 linestyle='-', linewidth=2, figsize=(12, 10));

                MY = Mumbai.groupby("YEAR").mean()['ANNUAL'].plot(ylim=(50, 7000), color='orange', marker='o',
                                                                  linestyle='-', linewidth=2, figsize=(12, 10));
                plt.xlabel('Year', fontsize=20)
                plt.ylabel('T,D,and M Annual Rainfall (in mm)', fontsize=20)
                plt.title(' T,D,and M Annual Rainfall from Year 1901 to 2015', fontsize=25)
                plt.legend(['Tamilnadu', 'Delhi', 'Mumbai'])
                TY.tick_params(labelsize=15)
                DY.tick_params(labelsize=15)
                MY.tick_params(labelsize=15)
                plt.grid()
                plt.show()
                
                 # Visualizing annual rainfall over the years(1901-2015) in India
                ax = data.groupby("YEAR").mean()['ANNUAL'].plot(ylim=(1000, 2000), color='r', linestyle='-',linewidth=2, figsize=(12, 10));
                plt.xlabel('Year', fontsize=20)
                plt.ylabel('Annual Rainfall (in mm)', fontsize=20)
                plt.title('Annual Rainfall from Year 1901 to 2015 in India', fontsize=25)
                plt.legend(['India'])
                ax.tick_params(labelsize=15)
                plt.grid()
                plt.show()
                

                # Visualizing annual rainfall over the years(1901-2015) in Tamilnadu
                TY = Tamilnadu.groupby("YEAR").mean()['ANNUAL'].plot(ylim=(50, 1500), color='green',
                                                                     linestyle='-', linewidth=2, figsize=(12, 10));
                plt.xlabel('Year', fontsize=20)
                plt.ylabel('Tamilnadu Annual Rainfall (in mm)', fontsize=20)
                plt.title('Tamilnadu Annual Rainfall from Year 1901 to 2015', fontsize=25)
                plt.legend(['Tamilnadu'])
                TY.tick_params(labelsize=15)
                plt.grid()
                plt.show()

                # Visualizing annual rainfall over the years(1901-2015) in delhi
                DY = Delhi.groupby("YEAR").mean()['ANNUAL'].plot(ylim=(50, 6500), color='violet',
                                                                 linestyle='-', linewidth=2, figsize=(12, 10));
                plt.xlabel('Year', fontsize=20)
                plt.ylabel('Delhi Annual Rainfall (in mm)', fontsize=20)
                plt.title('Delhi Annual Rainfall from Year 1901 to 2015', fontsize=25)
                plt.legend(['Delhi'])
                DY.tick_params(labelsize=15)
                plt.grid()
                plt.show()

                # Visualizing annual rainfall over the years(1901-2015) in mumbai
                MY = Mumbai.groupby("YEAR").mean()['ANNUAL'].plot(ylim=(1500, 6500), color='orange',
                                                                  linestyle='-', linewidth=2, figsize=(12, 10));
                plt.xlabel('Year', fontsize=20)
                plt.ylabel('Mumbai Annual Rainfall (in mm)', fontsize=20)
                plt.title('Mumbai Annual Rainfall from Year 1901 to 2015', fontsize=25)
                plt.legend(['Mumbai'])
                ax.tick_params(labelsize=15)
                plt.grid()
                plt.show()

                # Visualizing annual rainfall over the years(1901-2015) in t,d,m
                TY = Tamilnadu.groupby("YEAR").mean()['ANNUAL'].plot(ylim=(50, 7000), color='green',
                                                                     linestyle='-', linewidth=2, figsize=(12, 10));
                DY = Delhi.groupby("YEAR").mean()['ANNUAL'].plot(ylim=(50, 7000), color='violet',
                                                                 linestyle='-', linewidth=2, figsize=(12, 10));

                MY = Mumbai.groupby("YEAR").mean()['ANNUAL'].plot(ylim=(50, 7000), color='orange',
                                                                  linestyle='-', linewidth=2, figsize=(12, 10));
                plt.xlabel('Year', fontsize=20)
                plt.ylabel('T,D,and M Annual Rainfall (in mm)', fontsize=20)
                plt.title('T,D,and M Annual Rainfall from Year 1901 to 2015', fontsize=25)
                plt.legend(['Tamilnadu', 'Delhi', 'Mumbai'])
                TY.tick_params(labelsize=15)
                DY.tick_params(labelsize=15)
                MY.tick_params(labelsize=15)
                plt.grid()
                plt.show()
                
                tempdata_selected = data[data["SUBDIVISION"].isin(["MUMBAI", "DELHI", "TAMIL NADU"])]
                tr_avg_temps = tempdata_selected[tempdata_selected["SUBDIVISION"]=="MUMBAI"]["ANNUAL"]
                br_avg_temps = tempdata_selected[tempdata_selected["SUBDIVISION"]=="DELHI"]["ANNUAL"]
                us_avg_temps = tempdata_selected[tempdata_selected["SUBDIVISION"]=="TAMIL NADU"]["ANNUAL"]
                plt.xlabel('Year', fontsize=10)
                plt.ylabel('T,D,and M Annual Rainfall (in mm)', fontsize=10)
                plt.title('T,D,and M Annual Rainfall from Year 1901 to 2015', fontsize=10)
                plt.legend(['Tamilnadu', 'Delhi', 'Mumbai'])
                sns.distplot(tr_avg_temps)
                sns.distplot(us_avg_temps)
                sns.distplot(br_avg_temps)
                plt.legend(['Tamilnadu', 'Delhi', 'Mumbai'])
                plt.show()

        elif inp2 == "temp" or inp2 == "temperature":
            if inp3 == "bar" or inp3 == "barchar":
                T = tempdata_selected[tempdata_selected["Country"] == cdata[2]]["AverageTemperature"]
                D = tempdata_selected[tempdata_selected["Country"] == cdata[1]]["AverageTemperature"]
                M = tempdata_selected[tempdata_selected["Country"] == cdata[0]]["AverageTemperature"]

                plt.subplots(figsize=(16, 10))
                plt.xlabel('Quarter', fontsize=15)
                plt.ylabel('Quarterly Rainfall (in mm)', fontsize=15)
                plt.title('Quarterly Rainfall in Tamilnadu,Delhi and Mumbai', fontsize=20)
                X = np.arange(6)
                bar1 = plt.bar(0.00, T, color='g', width=0.25)
                bar2 = plt.bar(0.25, D, color='b', width=0.25)
                bar3 = plt.bar(0.50, M, color='orange', width=0.25)

                plt.legend((bar1, bar2, bar3), ('Tamilnadu', 'Delhi', 'Mumbai'))
                plt.grid()
                # plt.xticks(X+0.25,['1900','1920','1940','1960','1980','2000'])
                plt.show()
            else:
                sns.distplot(tr_avg_temps)
                sns.distplot(us_avg_temps)
                sns.distplot(br_avg_temps)

                cdata = tempdata_selected["Country"].unique()
                for c in cdata:
                    sns.distplot(tempdata_selected[tempdata_selected["Country"] == c]["AverageTemperature"])

                sns.set_style("whitegrid")
                plt.legend(['Mumbai','Delhi','Tamilnadu'])
                plt.figure(figsize=(15, 5))

                for c in cdata:
                    sns.distplot(tempdata_selected[tempdata_selected["Country"] == c]["AverageTemperature"])

                plt.legend(cdata)

                sns.set_style("whitegrid")
                plt.figure(figsize=(15, 5))
                color = ["green", "blue", "orange"]

                for color, c in zip(color, cdata):
                    sns.distplot(tempdata_selected[tempdata_selected["Country"] == c]["AverageTemperature"])
                    cmean = tempdata_selected[tempdata_selected["Country"] == c]["AverageTemperature"].mean()
                    plt.vlines(cmean, 0, 0.16, color=color)

                plt.legend(cdata)

                tempdata_selected.columns[1:3]

                colv = tempdata_selected.columns[1:3]
                cdata = tempdata_selected["Country"].unique()
                plt.figure(figsize=(15, 5))

                for col in colv:
                    plt.figure(figsize=(15, 5))
                    for c in cdata:
                        sns.distplot(tempdata_selected[tempdata_selected["Country"] == c][col])
                    plt.legend(['Mumbai','Delhi','Tamilnadu'])
                    plt.show()

                trData = tempdata_selected[(tempdata_selected["Country"] == "Mumbai") & (tempdata_selected["dt"] > "01.01.1900")]
                

                trData_mean = trData.groupby(trData["dt"].dt.to_period("Y")).mean()
                trData_mean = trData_mean.reset_index()
                
                trData_mean["dt"] = trData_mean["dt"].astype("string").astype("datetime64")
                plt.figure(figsize=(15, 5))

                sns.lineplot(x="dt", y="AverageTemperature", data=trData_mean,color='b')
                plt.legend(['Mumbai'])
                
                trData = tempdata_selected[(tempdata_selected["Country"] == "Delhi") & (tempdata_selected["dt"] > "01.01.1900")]
                

                trData_mean = trData.groupby(trData["dt"].dt.to_period("Y")).mean()
                trData_mean = trData_mean.reset_index()
                
                trData_mean["dt"] = trData_mean["dt"].astype("string").astype("datetime64")
                plt.figure(figsize=(15, 5))

                sns.lineplot(x="dt", y="AverageTemperature", data=trData_mean,color='orange')
                plt.legend(['Delhi'])
                
                trData = tempdata_selected[(tempdata_selected["Country"] == "Tamilnadu") & (tempdata_selected["dt"] > "01.01.1900")]
                

                trData_mean = trData.groupby(trData["dt"].dt.to_period("Y")).mean()
                trData_mean = trData_mean.reset_index()
                
                trData_mean["dt"] = trData_mean["dt"].astype("string").astype("datetime64")
                plt.figure(figsize=(15, 5))

                sns.lineplot(x="dt", y="AverageTemperature", data=trData_mean,color='g')
                plt.legend(['Tamilnadu'])
                
                data_1900 = tempdata_selected[tempdata_selected["dt"] > "01.01.1900"]
                
                data_means = data_1900.groupby(["Country", data_1900["dt"].dt.to_period("Y")]).mean()
                data_means = data_means.reset_index()
                data_means["dt"] = data_means["dt"].astype("string").astype("datetime64")
                
                for column in data_means.columns[2:4]:
                    plt.figure(figsize=(15, 5))

                    for c in data_means["Country"].unique():
                        data = data_means[data_means["Country"] == c]
                        sns.lineplot(x="dt", y=col, data=data)
                    plt.legend(['Mumbai','Delhi','Tamilnadu'])

    elif inp1 == "month" or inp1 == "monthly":

        if inp2 == "rain" or inp2 == "rainfall":

            if inp3 == "bar" or inp3 == "barchart":
                # Average monthly rainfall in India
                ax = data[['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC']].mean()
                plt.subplots(figsize=(16, 10))
                plt.xlabel('Month', fontsize=30)
                plt.ylabel('Monthly Rainfall (in mm)', fontsize=30)
                plt.title('Monthly Rainfall in Subdivisions of India', fontsize=25)
                
               
                X = np.arange(11)
                bar1 = plt.bar(X + 0.00, ax, color='b', width=0.25)
                plt.legend(['Subdivisions'])
                plt.grid()
                plt.xticks(X + 0.25, ['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC'])
                plt.show()

                # Average monthly rainfall in Tamilnadu
                T = Tamilnadu[['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC']].mean()
                plt.subplots(figsize=(16, 10))
                plt.xlabel('Month', fontsize=30)
                plt.ylabel('Monthly Rainfall (in mm)', fontsize=30)
                plt.title('Monthly Rainfall in Tamilnadu', fontsize=25)
                
                X = np.arange(11)
                plt.bar(X + 0.00, T, color='lightgreen', width=0.25)
                

                plt.legend(['Tamilnadu'])
                plt.grid()
                plt.xticks(X + 0.25, ['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC'])
                plt.show()

                # Average monthly rainfall in Delhi
                D = Delhi[['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC']].mean()
                plt.subplots(figsize=(16, 10))
                plt.xlabel('Month', fontsize=30)
                plt.ylabel('Monthly Rainfall (in mm)', fontsize=30)
                plt.title('Monthly Rainfall in Delhi', fontsize=25)
                
                X = np.arange(11)
                
                bar2 = plt.bar(X + 0.25, D, color='violet', width=0.25)
                

                plt.legend(['Delhi'])
                plt.grid()
                plt.xticks(X + 0.25, ['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC'])
                plt.show()
                
                

                # Average monthly rainfall in Mumbai
                M = Mumbai[['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC']].mean()
                plt.subplots(figsize=(16, 10))
                plt.xlabel('Month', fontsize=30)
                plt.ylabel('Monthly Rainfall (in mm)', fontsize=30)
                plt.title('Monthly Rainfall in Mumbai', fontsize=25)
                
                X = np.arange(11)
                
                bar3 = plt.bar(X + 0.50, M, color='orange', width=0.25)

                plt.legend(['Mumbai'])
                plt.grid()
                plt.xticks(X + 0.25, ['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC'])
                plt.show()


                # Average monthly rainfall in Tamilnadu
                T = Tamilnadu[['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC']].mean()

                D = Delhi[['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC']].mean()

                M = Mumbai[['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC']].mean()

                plt.subplots(figsize=(16, 10))
                plt.xlabel('Quarter', fontsize=15)
                plt.ylabel('Quarterly Rainfall (in mm)', fontsize=15)
                plt.title('Quarterly Rainfall in Tamilnadu,Delhi and Mumbai', fontsize=20)
                X = np.arange(11)
                bar1 = plt.bar(X + 0.00, T, color='lightgreen', width=0.25)
                bar2 = plt.bar(X + 0.25, D, color='violet', width=0.25)
                bar3 = plt.bar(X + 0.50, M, color='orange', width=0.25)

                plt.legend((bar1, bar2, bar3), ('Tamilnadu', 'Delhi', 'Mumbai'))
                plt.grid()
                plt.xticks(X + 0.25, ['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC'])
                plt.show()
            else:
                print("No Data Found")
        elif inp2 == "temp" or inp2 == "temperature":
            if inp3 == "bar" or inp3 == "barchar":
                print("No Data Found")
            else:
                print("No Data Found")
# Out:
# please Enter 'Yearly' or 'Monthly' year
# What type of data you want about the Weather - 'Rain' or 'Temperature' temp
# What Type of Graph you Want - 'Line' or 'Barchart' line
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
    inp1 = input("please Enter 'Yearly' or 'Monthly' ")
    inp1.lower()
    inp2 = input("What type of data you want about the Weather - 'Rain' or 'Temperature' ")
    inp2.lower()
    inp3 = input("What Type of Graph you Want - 'Line' or 'Barchart' ")
    inp3.lower()
    if inp1 == "year" or inp1 == "yearly":
        if inp2 == "rain" or inp2 == "rainfall":
            if inp3 == "bar" or inp3 == "barchart":

                data[['SUBDIVISION', 'ANNUAL']].sort_values(by='ANNUAL', ascending=False).head(20)



                # Average monthly rainfall in India
                ax = data[['Jan-Feb', 'Mar-May', 'Jun-Sep', 'Oct-Dec']].mean().plot.bar(width=0.5, linewidth=2,
                                                                                        figsize=(16, 10))
                plt.xlabel('Quarter', fontsize=15)
                plt.ylabel('Quarterly Rainfall (in mm)', fontsize=15)
                plt.title('Quarterly Rainfall in India', fontsize=20)
                plt.legend(['Subdivisions'])
                ax.tick_params(labelsize=15)
                plt.grid()
                plt.show()



                # Getting rainfall data for Tamilnadu
                Tamilnadu = data.loc[((data['SUBDIVISION'] == 'TAMIL NADU'))]



                # Average monthly rainfall in Tamilnadu
                TM = Tamilnadu[['Jan-Feb', 'Mar-May', 'Jun-Sep', 'Oct-Dec']].mean().plot.bar(width=0.5, linewidth=2,
                                                                                             figsize=(16, 10),
                                                                                             color='lightgreen')
                plt.xlabel('Quarter', fontsize=15)
                plt.ylabel('Quarterly Rainfall (in mm)', fontsize=15)
                plt.title('Quarterly Rainfall in Tamilnadu', fontsize=20)
                plt.legend(['Tamilnadu'])
                TM.tick_params(labelsize=15)
                plt.grid()
                plt.show()



                print('Average annual rainfall received by Tamilnadu = ', int(Tamilnadu['ANNUAL'].mean()), 'mm')
                a = Tamilnadu[Tamilnadu['YEAR'] == 1917]

                # Getting rainfall data for Delhi
                Delhi = data.loc[(data['SUBDIVISION'] == 'DELHI')]



                # Average monthly rainfall in Arunachal Pradesh
                DM = Delhi[['Jan-Feb', 'Mar-May', 'Jun-Sep', 'Oct-Dec']].mean().plot.bar(width=0.5, linewidth=2,
                                                                                         figsize=(16, 10),
                                                                                         color="violet")
                plt.xlabel('Quarter', fontsize=15)
                plt.ylabel('Quarterly Rainfall (in mm)', fontsize=15)
                plt.title('Quarterly Rainfall in Delhi', fontsize=20)
                plt.legend(['Delhi'])
                DM.tick_params(labelsize=15)
                plt.grid()
                plt.show()



                print('Average annual rainfall received by Arunachal Pradesh = ', int(Delhi['ANNUAL'].mean()), 'mm')
                a = Delhi[Delhi['YEAR'] == 1948]

                # Getting rainfall data for Mumbai
                Mumbai = data.loc[(data['SUBDIVISION'] == 'MUMBAI')]



                # Average monthly rainfall in mumbai
                MM = Mumbai[['Jan-Feb', 'Mar-May', 'Jun-Sep', 'Oct-Dec']].mean().plot.bar(width=0.5, linewidth=2,
                                                                                          figsize=(16, 10),
                                                                                          color="orange")
                plt.xlabel('Quarter', fontsize=15)
                plt.ylabel('Quarterly Rainfall (in mm)', fontsize=15)
                plt.title('Quarterly Rainfall in Mumbai', fontsize=20)
                plt.legend(['Mumbai'])
                MM.tick_params(labelsize=15)
                plt.grid()
                plt.show()



                # Average monthly rainfall in t,M,D

                DM = Delhi[['Jan-Feb', 'Mar-May', 'Jun-Sep', 'Oct-Dec']].mean()

                TM = Tamilnadu[['Jan-Feb', 'Mar-May', 'Jun-Sep', 'Oct-Dec']].mean()
                MM = Mumbai[['Jan-Feb', 'Mar-May', 'Jun-Sep', 'Oct-Dec']].mean()

                plt.subplots(figsize=(16, 10))
                plt.xlabel('Quarter', fontsize=15)
                plt.ylabel('Quarterly Rainfall (in mm)', fontsize=15)
                plt.title('Quarterly Rainfall in Tamilnadu,Delhi and Mumbai', fontsize=20)
                X = np.arange(4)
                bar1 = plt.bar(X + 0.00, TM, color='lightgreen', width=0.25)
                bar2 = plt.bar(X + 0.25, DM, color='violet', width=0.25)
                bar3 = plt.bar(X + 0.50, MM, color='orange', width=0.25)

                plt.legend((bar1, bar2, bar3), ('Tamilnadu', 'Delhi', 'Mumbai'))
                plt.grid()
                plt.xticks(X + 0.25, ['Jan-Feb', 'Mar-May', 'Jun-Sep', 'Oct-Dec'])
                plt.show()




            else:
                
                # Visualizing annual rainfall over the years(1901-2015) in India
                ax = data.groupby("YEAR").mean()['ANNUAL'].plot(ylim=(1000, 2000), color='r', marker='o', linestyle='-',linewidth=2, figsize=(12, 10));
                plt.xlabel('Year', fontsize=20)
                plt.ylabel('Annual Rainfall (in mm)', fontsize=20)
                plt.title('Annual Rainfall from Year 1901 to 2015 in India', fontsize=25)
                plt.legend(['India'])
                ax.tick_params(labelsize=15)
                plt.grid()
                plt.show()
                

                # Visualizing annual rainfall over the years(1901-2015) in Tamilnadu
                TY = Tamilnadu.groupby("YEAR").mean()['ANNUAL'].plot(ylim=(50, 1500), color='green', marker='o',
                                                                     linestyle='-', linewidth=2, figsize=(12, 10));
                plt.xlabel('Year', fontsize=20)
                plt.ylabel('Tamilnadu Annual Rainfall (in mm)', fontsize=20)
                plt.title('Tamilnadu Annual Rainfall from Year 1901 to 2015', fontsize=25)
                plt.legend(['Tamilnadu'])
                TY.tick_params(labelsize=15)
                plt.grid()
                plt.show()

                # Visualizing annual rainfall over the years(1901-2015) in delhi
                DY = Delhi.groupby("YEAR").mean()['ANNUAL'].plot(ylim=(50, 6500), color='violet', marker='o',
                                                                 linestyle='-', linewidth=2, figsize=(12, 10));
                plt.xlabel('Year', fontsize=20)
                plt.ylabel('Delhi Annual Rainfall (in mm)', fontsize=20)
                plt.title('Delhi Annual Rainfall from Year 1901 to 2015', fontsize=25)
                plt.legend(['Delhi'])
                DY.tick_params(labelsize=15)
                plt.grid()
                plt.show()

                # Visualizing annual rainfall over the years(1901-2015) in mumbai
                MY = Mumbai.groupby("YEAR").mean()['ANNUAL'].plot(ylim=(1500, 6500), color='orange', marker='o',
                                                                  linestyle='-', linewidth=2, figsize=(12, 10));
                plt.xlabel('Year', fontsize=20)
                plt.ylabel('Mumbai Annual Rainfall (in mm)', fontsize=20)
                plt.title('Mumbai Annual Rainfall from Year 1901 to 2015', fontsize=25)
                plt.legend(['Mumbai'])
                ax.tick_params(labelsize=15)
                plt.grid()
                plt.show()

                # Visualizing annual rainfall over the years(1901-2015) in t,m,d
                TY = Tamilnadu.groupby("YEAR").mean()['ANNUAL'].plot(ylim=(50, 7000), color='green', marker='o',
                                                                     linestyle='-', linewidth=2, figsize=(12, 10));
                DY = Delhi.groupby("YEAR").mean()['ANNUAL'].plot(ylim=(50, 7000), color='violet', marker='o',
                                                                 linestyle='-', linewidth=2, figsize=(12, 10));

                MY = Mumbai.groupby("YEAR").mean()['ANNUAL'].plot(ylim=(50, 7000), color='orange', marker='o',
                                                                  linestyle='-', linewidth=2, figsize=(12, 10));
                plt.xlabel('Year', fontsize=20)
                plt.ylabel('T,D,and M Annual Rainfall (in mm)', fontsize=20)
                plt.title(' T,D,and M Annual Rainfall from Year 1901 to 2015', fontsize=25)
                plt.legend(['Tamilnadu', 'Delhi', 'Mumbai'])
                TY.tick_params(labelsize=15)
                DY.tick_params(labelsize=15)
                MY.tick_params(labelsize=15)
                plt.grid()
                plt.show()
                
                 # Visualizing annual rainfall over the years(1901-2015) in India
                ax = data.groupby("YEAR").mean()['ANNUAL'].plot(ylim=(1000, 2000), color='r', linestyle='-',linewidth=2, figsize=(12, 10));
                plt.xlabel('Year', fontsize=20)
                plt.ylabel('Annual Rainfall (in mm)', fontsize=20)
                plt.title('Annual Rainfall from Year 1901 to 2015 in India', fontsize=25)
                plt.legend(['India'])
                ax.tick_params(labelsize=15)
                plt.grid()
                plt.show()
                

                # Visualizing annual rainfall over the years(1901-2015) in Tamilnadu
                TY = Tamilnadu.groupby("YEAR").mean()['ANNUAL'].plot(ylim=(50, 1500), color='green',
                                                                     linestyle='-', linewidth=2, figsize=(12, 10));
                plt.xlabel('Year', fontsize=20)
                plt.ylabel('Tamilnadu Annual Rainfall (in mm)', fontsize=20)
                plt.title('Tamilnadu Annual Rainfall from Year 1901 to 2015', fontsize=25)
                plt.legend(['Tamilnadu'])
                TY.tick_params(labelsize=15)
                plt.grid()
                plt.show()

                # Visualizing annual rainfall over the years(1901-2015) in delhi
                DY = Delhi.groupby("YEAR").mean()['ANNUAL'].plot(ylim=(50, 6500), color='violet',
                                                                 linestyle='-', linewidth=2, figsize=(12, 10));
                plt.xlabel('Year', fontsize=20)
                plt.ylabel('Delhi Annual Rainfall (in mm)', fontsize=20)
                plt.title('Delhi Annual Rainfall from Year 1901 to 2015', fontsize=25)
                plt.legend(['Delhi'])
                DY.tick_params(labelsize=15)
                plt.grid()
                plt.show()

                # Visualizing annual rainfall over the years(1901-2015) in mumbai
                MY = Mumbai.groupby("YEAR").mean()['ANNUAL'].plot(ylim=(1500, 6500), color='orange',
                                                                  linestyle='-', linewidth=2, figsize=(12, 10));
                plt.xlabel('Year', fontsize=20)
                plt.ylabel('Mumbai Annual Rainfall (in mm)', fontsize=20)
                plt.title('Mumbai Annual Rainfall from Year 1901 to 2015', fontsize=25)
                plt.legend(['Mumbai'])
                ax.tick_params(labelsize=15)
                plt.grid()
                plt.show()

                # Visualizing annual rainfall over the years(1901-2015) in t,d,m
                TY = Tamilnadu.groupby("YEAR").mean()['ANNUAL'].plot(ylim=(50, 7000), color='green',
                                                                     linestyle='-', linewidth=2, figsize=(12, 10));
                DY = Delhi.groupby("YEAR").mean()['ANNUAL'].plot(ylim=(50, 7000), color='violet',
                                                                 linestyle='-', linewidth=2, figsize=(12, 10));

                MY = Mumbai.groupby("YEAR").mean()['ANNUAL'].plot(ylim=(50, 7000), color='orange',
                                                                  linestyle='-', linewidth=2, figsize=(12, 10));
                plt.xlabel('Year', fontsize=20)
                plt.ylabel('T,D,and M Annual Rainfall (in mm)', fontsize=20)
                plt.title('T,D,and M Annual Rainfall from Year 1901 to 2015', fontsize=25)
                plt.legend(['Tamilnadu', 'Delhi', 'Mumbai'])
                TY.tick_params(labelsize=15)
                DY.tick_params(labelsize=15)
                MY.tick_params(labelsize=15)
                plt.grid()
                plt.show()
                
                tempdata_selected = data[data["SUBDIVISION"].isin(["MUMBAI", "DELHI", "TAMIL NADU"])]
                tr_avg_temps = tempdata_selected[tempdata_selected["SUBDIVISION"]=="MUMBAI"]["ANNUAL"]
                br_avg_temps = tempdata_selected[tempdata_selected["SUBDIVISION"]=="DELHI"]["ANNUAL"]
                us_avg_temps = tempdata_selected[tempdata_selected["SUBDIVISION"]=="TAMIL NADU"]["ANNUAL"]
                plt.xlabel('Year', fontsize=10)
                plt.ylabel('T,D,and M Annual Rainfall (in mm)', fontsize=10)
                plt.title('T,D,and M Annual Rainfall from Year 1901 to 2015', fontsize=10)
                plt.legend(['Tamilnadu', 'Delhi', 'Mumbai'])
                sns.distplot(tr_avg_temps)
                sns.distplot(us_avg_temps)
                sns.distplot(br_avg_temps)
                plt.legend(['Tamilnadu', 'Delhi', 'Mumbai'])
                plt.show()

        elif inp2 == "temp" or inp2 == "temperature":
            if inp3 == "bar" or inp3 == "barchar":
                T = tempdata_selected[tempdata_selected["Country"] == cdata[2]]["AverageTemperature"]
                D = tempdata_selected[tempdata_selected["Country"] == cdata[1]]["AverageTemperature"]
                M = tempdata_selected[tempdata_selected["Country"] == cdata[0]]["AverageTemperature"]

                plt.subplots(figsize=(16, 10))
                plt.xlabel('Quarter', fontsize=15)
                plt.ylabel('Quarterly Rainfall (in mm)', fontsize=15)
                plt.title('Quarterly Rainfall in Tamilnadu,Delhi and Mumbai', fontsize=20)
                X = np.arange(6)
                bar1 = plt.bar(0.00, T, color='g', width=0.25)
                bar2 = plt.bar(0.25, D, color='b', width=0.25)
                bar3 = plt.bar(0.50, M, color='orange', width=0.25)

                plt.legend((bar1, bar2, bar3), ('Tamilnadu', 'Delhi', 'Mumbai'))
                plt.grid()
                # plt.xticks(X+0.25,['1900','1920','1940','1960','1980','2000'])
                plt.show()
            else:
                sns.distplot(tr_avg_temps)
                sns.distplot(us_avg_temps)
                sns.distplot(br_avg_temps)

                cdata = tempdata_selected["Country"].unique()
                for c in cdata:
                    sns.distplot(tempdata_selected[tempdata_selected["Country"] == c]["AverageTemperature"])

                sns.set_style("whitegrid")
                plt.legend(['Mumbai','Delhi','Tamilnadu'])
                plt.figure(figsize=(15, 5))

                for c in cdata:
                    sns.distplot(tempdata_selected[tempdata_selected["Country"] == c]["AverageTemperature"])

                plt.legend(cdata)

                sns.set_style("whitegrid")
                plt.figure(figsize=(15, 5))
                color = ["green", "blue", "orange"]

                for color, c in zip(color, cdata):
                    sns.distplot(tempdata_selected[tempdata_selected["Country"] == c]["AverageTemperature"])
                    cmean = tempdata_selected[tempdata_selected["Country"] == c]["AverageTemperature"].mean()
                    plt.vlines(cmean, 0, 0.16, color=color)

                plt.legend(cdata)

                tempdata_selected.columns[1:3]

                colv = tempdata_selected.columns[1:3]
                cdata = tempdata_selected["Country"].unique()
                plt.figure(figsize=(15, 5))

                for col in colv:
                    plt.figure(figsize=(15, 5))
                    for c in cdata:
                        sns.distplot(tempdata_selected[tempdata_selected["Country"] == c][col])
                    plt.legend(['Mumbai','Delhi','Tamilnadu'])
                    plt.show()

                trData = tempdata_selected[(tempdata_selected["Country"] == "Mumbai") & (tempdata_selected["dt"] > "01.01.1900")]
                

                trData_mean = trData.groupby(trData["dt"].dt.to_period("Y")).mean()
                trData_mean = trData_mean.reset_index()
                
                trData_mean["dt"] = trData_mean["dt"].astype("string").astype("datetime64")
                plt.figure(figsize=(15, 5))

                sns.lineplot(x="dt", y="AverageTemperature", data=trData_mean,color='b')
                plt.legend(['Mumbai'])
                
                trData = tempdata_selected[(tempdata_selected["Country"] == "Delhi") & (tempdata_selected["dt"] > "01.01.1900")]
                

                trData_mean = trData.groupby(trData["dt"].dt.to_period("Y")).mean()
                trData_mean = trData_mean.reset_index()
                
                trData_mean["dt"] = trData_mean["dt"].astype("string").astype("datetime64")
                plt.figure(figsize=(15, 5))

                sns.lineplot(x="dt", y="AverageTemperature", data=trData_mean,color='orange')
                plt.legend(['Delhi'])
                
                trData = tempdata_selected[(tempdata_selected["Country"] == "Tamilnadu") & (tempdata_selected["dt"] > "01.01.1900")]
                

                trData_mean = trData.groupby(trData["dt"].dt.to_period("Y")).mean()
                trData_mean = trData_mean.reset_index()
                
                trData_mean["dt"] = trData_mean["dt"].astype("string").astype("datetime64")
                plt.figure(figsize=(15, 5))

                sns.lineplot(x="dt", y="AverageTemperature", data=trData_mean,color='g')
                plt.legend(['Tamilnadu'])
                
                data_1900 = tempdata_selected[tempdata_selected["dt"] > "01.01.1900"]
                
                data_means = data_1900.groupby(["Country", data_1900["dt"].dt.to_period("Y")]).mean()
                data_means = data_means.reset_index()
                data_means["dt"] = data_means["dt"].astype("string").astype("datetime64")
                
                for column in data_means.columns[2:4]:
                    plt.figure(figsize=(15, 5))

                    for c in data_means["Country"].unique():
                        data = data_means[data_means["Country"] == c]
                        sns.lineplot(x="dt", y=col, data=data)
                    plt.legend(['Mumbai','Delhi','Tamilnadu'])

    elif inp1 == "month" or inp1 == "monthly":

        if inp2 == "rain" or inp2 == "rainfall":

            if inp3 == "bar" or inp3 == "barchart":
                # Average monthly rainfall in India
                ax = data[['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC']].mean()
                plt.subplots(figsize=(16, 10))
                plt.xlabel('Month', fontsize=30)
                plt.ylabel('Monthly Rainfall (in mm)', fontsize=30)
                plt.title('Monthly Rainfall in Subdivisions of India', fontsize=25)
                
               
                X = np.arange(11)
                bar1 = plt.bar(X + 0.00, ax, color='b', width=0.25)
                plt.legend(['Subdivisions'])
                plt.grid()
                plt.xticks(X + 0.25, ['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC'])
                plt.show()

                # Average monthly rainfall in Tamilnadu
                T = Tamilnadu[['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC']].mean()
                plt.subplots(figsize=(16, 10))
                plt.xlabel('Month', fontsize=30)
                plt.ylabel('Monthly Rainfall (in mm)', fontsize=30)
                plt.title('Monthly Rainfall in Tamilnadu', fontsize=25)
                
                X = np.arange(11)
                plt.bar(X + 0.00, T, color='lightgreen', width=0.25)
                

                plt.legend(['Tamilnadu'])
                plt.grid()
                plt.xticks(X + 0.25, ['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC'])
                plt.show()

                # Average monthly rainfall in Delhi
                D = Delhi[['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC']].mean()
                plt.subplots(figsize=(16, 10))
                plt.xlabel('Month', fontsize=30)
                plt.ylabel('Monthly Rainfall (in mm)', fontsize=30)
                plt.title('Monthly Rainfall in Delhi', fontsize=25)
                
                X = np.arange(11)
                
                bar2 = plt.bar(X + 0.25, D, color='violet', width=0.25)
                

                plt.legend(['Delhi'])
                plt.grid()
                plt.xticks(X + 0.25, ['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC'])
                plt.show()
                
                

                # Average monthly rainfall in Mumbai
                M = Mumbai[['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC']].mean()
                plt.subplots(figsize=(16, 10))
                plt.xlabel('Month', fontsize=30)
                plt.ylabel('Monthly Rainfall (in mm)', fontsize=30)
                plt.title('Monthly Rainfall in Mumbai', fontsize=25)
                
                X = np.arange(11)
                
                bar3 = plt.bar(X + 0.50, M, color='orange', width=0.25)

                plt.legend(['Mumbai'])
                plt.grid()
                plt.xticks(X + 0.25, ['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC'])
                plt.show()


                # Average monthly rainfall in Tamilnadu
                T = Tamilnadu[['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC']].mean()

                D = Delhi[['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC']].mean()

                M = Mumbai[['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC']].mean()

                plt.subplots(figsize=(16, 10))
                plt.xlabel('Quarter', fontsize=15)
                plt.ylabel('Quarterly Rainfall (in mm)', fontsize=15)
                plt.title('Quarterly Rainfall in Tamilnadu,Delhi and Mumbai', fontsize=20)
                X = np.arange(11)
                bar1 = plt.bar(X + 0.00, T, color='lightgreen', width=0.25)
                bar2 = plt.bar(X + 0.25, D, color='violet', width=0.25)
                bar3 = plt.bar(X + 0.50, M, color='orange', width=0.25)

                plt.legend((bar1, bar2, bar3), ('Tamilnadu', 'Delhi', 'Mumbai'))
                plt.grid()
                plt.xticks(X + 0.25, ['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC'])
                plt.show()
            else:
                print("No Data Found")
        elif inp2 == "temp" or inp2 == "temperature":
            if inp3 == "bar" or inp3 == "barchar":
                print("No Data Found")
            else:
                print("No Data Found")
# Out:
# please Enter 'Yearly' or 'Monthly' year
# What type of data you want about the Weather - 'Rain' or 'Temperature' rain
# What Type of Graph you Want - 'Line' or 'Barchart'
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
    inp1 = input("please Enter 'Yearly' or 'Monthly' ")
    inp1.lower()
    inp2 = input("What type of data you want about the Weather - 'Rain' or 'Temperature' ")
    inp2.lower()
    inp3 = input("What Type of Graph you Want - 'Line' or 'Barchart' ")
    inp3.lower()
    if inp1 == "year" or inp1 == "yearly":
        if inp2 == "rain" or inp2 == "rainfall":
            if inp3 == "bar" or inp3 == "barchart":

                data[['SUBDIVISION', 'ANNUAL']].sort_values(by='ANNUAL', ascending=False).head(20)



                # Average monthly rainfall in India
                ax = data[['Jan-Feb', 'Mar-May', 'Jun-Sep', 'Oct-Dec']].mean().plot.bar(width=0.5, linewidth=2,
                                                                                        figsize=(16, 10))
                plt.xlabel('Quarter', fontsize=15)
                plt.ylabel('Quarterly Rainfall (in mm)', fontsize=15)
                plt.title('Quarterly Rainfall in India', fontsize=20)
                plt.legend(['Subdivisions'])
                ax.tick_params(labelsize=15)
                plt.grid()
                plt.show()



                # Getting rainfall data for Tamilnadu
                Tamilnadu = data.loc[((data['SUBDIVISION'] == 'TAMIL NADU'))]



                # Average monthly rainfall in Tamilnadu
                TM = Tamilnadu[['Jan-Feb', 'Mar-May', 'Jun-Sep', 'Oct-Dec']].mean().plot.bar(width=0.5, linewidth=2,
                                                                                             figsize=(16, 10),
                                                                                             color='lightgreen')
                plt.xlabel('Quarter', fontsize=15)
                plt.ylabel('Quarterly Rainfall (in mm)', fontsize=15)
                plt.title('Quarterly Rainfall in Tamilnadu', fontsize=20)
                plt.legend(['Tamilnadu'])
                TM.tick_params(labelsize=15)
                plt.grid()
                plt.show()



                print('Average annual rainfall received by Tamilnadu = ', int(Tamilnadu['ANNUAL'].mean()), 'mm')
                a = Tamilnadu[Tamilnadu['YEAR'] == 1917]

                # Getting rainfall data for Delhi
                Delhi = data.loc[(data['SUBDIVISION'] == 'DELHI')]



                # Average monthly rainfall in Arunachal Pradesh
                DM = Delhi[['Jan-Feb', 'Mar-May', 'Jun-Sep', 'Oct-Dec']].mean().plot.bar(width=0.5, linewidth=2,
                                                                                         figsize=(16, 10),
                                                                                         color="violet")
                plt.xlabel('Quarter', fontsize=15)
                plt.ylabel('Quarterly Rainfall (in mm)', fontsize=15)
                plt.title('Quarterly Rainfall in Delhi', fontsize=20)
                plt.legend(['Delhi'])
                DM.tick_params(labelsize=15)
                plt.grid()
                plt.show()



                print('Average annual rainfall received by Arunachal Pradesh = ', int(Delhi['ANNUAL'].mean()), 'mm')
                a = Delhi[Delhi['YEAR'] == 1948]

                # Getting rainfall data for Mumbai
                Mumbai = data.loc[(data['SUBDIVISION'] == 'MUMBAI')]



                # Average monthly rainfall in mumbai
                MM = Mumbai[['Jan-Feb', 'Mar-May', 'Jun-Sep', 'Oct-Dec']].mean().plot.bar(width=0.5, linewidth=2,
                                                                                          figsize=(16, 10),
                                                                                          color="orange")
                plt.xlabel('Quarter', fontsize=15)
                plt.ylabel('Quarterly Rainfall (in mm)', fontsize=15)
                plt.title('Quarterly Rainfall in Mumbai', fontsize=20)
                plt.legend(['Mumbai'])
                MM.tick_params(labelsize=15)
                plt.grid()
                plt.show()



                # Average monthly rainfall in t,M,D

                DM = Delhi[['Jan-Feb', 'Mar-May', 'Jun-Sep', 'Oct-Dec']].mean()

                TM = Tamilnadu[['Jan-Feb', 'Mar-May', 'Jun-Sep', 'Oct-Dec']].mean()
                MM = Mumbai[['Jan-Feb', 'Mar-May', 'Jun-Sep', 'Oct-Dec']].mean()

                plt.subplots(figsize=(16, 10))
                plt.xlabel('Quarter', fontsize=15)
                plt.ylabel('Quarterly Rainfall (in mm)', fontsize=15)
                plt.title('Quarterly Rainfall in Tamilnadu,Delhi and Mumbai', fontsize=20)
                X = np.arange(4)
                bar1 = plt.bar(X + 0.00, TM, color='lightgreen', width=0.25)
                bar2 = plt.bar(X + 0.25, DM, color='violet', width=0.25)
                bar3 = plt.bar(X + 0.50, MM, color='orange', width=0.25)

                plt.legend((bar1, bar2, bar3), ('Tamilnadu', 'Delhi', 'Mumbai'))
                plt.grid()
                plt.xticks(X + 0.25, ['Jan-Feb', 'Mar-May', 'Jun-Sep', 'Oct-Dec'])
                plt.show()




            else:
                
                # Visualizing annual rainfall over the years(1901-2015) in India
                ax = data.groupby("YEAR").mean()['ANNUAL'].plot(ylim=(1000, 2000), color='r', marker='o', linestyle='-',linewidth=2, figsize=(12, 10));
                plt.xlabel('Year', fontsize=20)
                plt.ylabel('Annual Rainfall (in mm)', fontsize=20)
                plt.title('Annual Rainfall from Year 1901 to 2015 in India', fontsize=25)
                plt.legend(['India'])
                ax.tick_params(labelsize=15)
                plt.grid()
                plt.show()
                

                # Visualizing annual rainfall over the years(1901-2015) in Tamilnadu
                TY = Tamilnadu.groupby("YEAR").mean()['ANNUAL'].plot(ylim=(50, 1500), color='green', marker='o',
                                                                     linestyle='-', linewidth=2, figsize=(12, 10));
                plt.xlabel('Year', fontsize=20)
                plt.ylabel('Tamilnadu Annual Rainfall (in mm)', fontsize=20)
                plt.title('Tamilnadu Annual Rainfall from Year 1901 to 2015', fontsize=25)
                plt.legend(['Tamilnadu'])
                TY.tick_params(labelsize=15)
                plt.grid()
                plt.show()

                # Visualizing annual rainfall over the years(1901-2015) in delhi
                DY = Delhi.groupby("YEAR").mean()['ANNUAL'].plot(ylim=(50, 6500), color='violet', marker='o',
                                                                 linestyle='-', linewidth=2, figsize=(12, 10));
                plt.xlabel('Year', fontsize=20)
                plt.ylabel('Delhi Annual Rainfall (in mm)', fontsize=20)
                plt.title('Delhi Annual Rainfall from Year 1901 to 2015', fontsize=25)
                plt.legend(['Delhi'])
                DY.tick_params(labelsize=15)
                plt.grid()
                plt.show()

                # Visualizing annual rainfall over the years(1901-2015) in mumbai
                MY = Mumbai.groupby("YEAR").mean()['ANNUAL'].plot(ylim=(1500, 6500), color='orange', marker='o',
                                                                  linestyle='-', linewidth=2, figsize=(12, 10));
                plt.xlabel('Year', fontsize=20)
                plt.ylabel('Mumbai Annual Rainfall (in mm)', fontsize=20)
                plt.title('Mumbai Annual Rainfall from Year 1901 to 2015', fontsize=25)
                plt.legend(['Mumbai'])
                ax.tick_params(labelsize=15)
                plt.grid()
                plt.show()

                # Visualizing annual rainfall over the years(1901-2015) in t,m,d
                TY = Tamilnadu.groupby("YEAR").mean()['ANNUAL'].plot(ylim=(50, 7000), color='green', marker='o',
                                                                     linestyle='-', linewidth=2, figsize=(12, 10));
                DY = Delhi.groupby("YEAR").mean()['ANNUAL'].plot(ylim=(50, 7000), color='violet', marker='o',
                                                                 linestyle='-', linewidth=2, figsize=(12, 10));

                MY = Mumbai.groupby("YEAR").mean()['ANNUAL'].plot(ylim=(50, 7000), color='orange', marker='o',
                                                                  linestyle='-', linewidth=2, figsize=(12, 10));
                plt.xlabel('Year', fontsize=20)
                plt.ylabel('T,D,and M Annual Rainfall (in mm)', fontsize=20)
                plt.title(' T,D,and M Annual Rainfall from Year 1901 to 2015', fontsize=25)
                plt.legend(['Tamilnadu', 'Delhi', 'Mumbai'])
                TY.tick_params(labelsize=15)
                DY.tick_params(labelsize=15)
                MY.tick_params(labelsize=15)
                plt.grid()
                plt.show()
                
                 # Visualizing annual rainfall over the years(1901-2015) in India
                ax = data.groupby("YEAR").mean()['ANNUAL'].plot(ylim=(1000, 2000), color='r', linestyle='-',linewidth=2, figsize=(12, 10));
                plt.xlabel('Year', fontsize=20)
                plt.ylabel('Annual Rainfall (in mm)', fontsize=20)
                plt.title('Annual Rainfall from Year 1901 to 2015 in India', fontsize=25)
                plt.legend(['India'])
                ax.tick_params(labelsize=15)
                plt.grid()
                plt.show()
                

                # Visualizing annual rainfall over the years(1901-2015) in Tamilnadu
                TY = Tamilnadu.groupby("YEAR").mean()['ANNUAL'].plot(ylim=(50, 1500), color='green',
                                                                     linestyle='-', linewidth=2, figsize=(12, 10));
                plt.xlabel('Year', fontsize=20)
                plt.ylabel('Tamilnadu Annual Rainfall (in mm)', fontsize=20)
                plt.title('Tamilnadu Annual Rainfall from Year 1901 to 2015', fontsize=25)
                plt.legend(['Tamilnadu'])
                TY.tick_params(labelsize=15)
                plt.grid()
                plt.show()

                # Visualizing annual rainfall over the years(1901-2015) in delhi
                DY = Delhi.groupby("YEAR").mean()['ANNUAL'].plot(ylim=(50, 6500), color='violet',
                                                                 linestyle='-', linewidth=2, figsize=(12, 10));
                plt.xlabel('Year', fontsize=20)
                plt.ylabel('Delhi Annual Rainfall (in mm)', fontsize=20)
                plt.title('Delhi Annual Rainfall from Year 1901 to 2015', fontsize=25)
                plt.legend(['Delhi'])
                DY.tick_params(labelsize=15)
                plt.grid()
                plt.show()

                # Visualizing annual rainfall over the years(1901-2015) in mumbai
                MY = Mumbai.groupby("YEAR").mean()['ANNUAL'].plot(ylim=(1500, 6500), color='orange',
                                                                  linestyle='-', linewidth=2, figsize=(12, 10));
                plt.xlabel('Year', fontsize=20)
                plt.ylabel('Mumbai Annual Rainfall (in mm)', fontsize=20)
                plt.title('Mumbai Annual Rainfall from Year 1901 to 2015', fontsize=25)
                plt.legend(['Mumbai'])
                ax.tick_params(labelsize=15)
                plt.grid()
                plt.show()

                # Visualizing annual rainfall over the years(1901-2015) in t,d,m
                TY = Tamilnadu.groupby("YEAR").mean()['ANNUAL'].plot(ylim=(50, 7000), color='green',
                                                                     linestyle='-', linewidth=2, figsize=(12, 10));
                DY = Delhi.groupby("YEAR").mean()['ANNUAL'].plot(ylim=(50, 7000), color='violet',
                                                                 linestyle='-', linewidth=2, figsize=(12, 10));

                MY = Mumbai.groupby("YEAR").mean()['ANNUAL'].plot(ylim=(50, 7000), color='orange',
                                                                  linestyle='-', linewidth=2, figsize=(12, 10));
                plt.xlabel('Year', fontsize=20)
                plt.ylabel('T,D,and M Annual Rainfall (in mm)', fontsize=20)
                plt.title('T,D,and M Annual Rainfall from Year 1901 to 2015', fontsize=25)
                plt.legend(['Tamilnadu', 'Delhi', 'Mumbai'])
                TY.tick_params(labelsize=15)
                DY.tick_params(labelsize=15)
                MY.tick_params(labelsize=15)
                plt.grid()
                plt.show()
                
                tempdata_selected = data[data["SUBDIVISION"].isin(["MUMBAI", "DELHI", "TAMIL NADU"])]
                tr_avg_temps = tempdata_selected[tempdata_selected["SUBDIVISION"]=="MUMBAI"]["ANNUAL"]
                br_avg_temps = tempdata_selected[tempdata_selected["SUBDIVISION"]=="DELHI"]["ANNUAL"]
                us_avg_temps = tempdata_selected[tempdata_selected["SUBDIVISION"]=="TAMIL NADU"]["ANNUAL"]
                plt.xlabel('Year', fontsize=10)
                plt.ylabel('T,D,and M Annual Rainfall (in mm)', fontsize=10)
                plt.title('T,D,and M Annual Rainfall from Year 1901 to 2015', fontsize=10)
                plt.legend(['Tamilnadu', 'Delhi', 'Mumbai'])
                sns.distplot(tr_avg_temps)
                sns.distplot(us_avg_temps)
                sns.distplot(br_avg_temps)
                plt.legend(['Tamilnadu', 'Delhi', 'Mumbai'])
                plt.show()

        elif inp2 == "temp" or inp2 == "temperature":
            if inp3 == "bar" or inp3 == "barchar":
                T = tempdata_selected[tempdata_selected["Country"] == cdata[2]]["AverageTemperature"]
                D = tempdata_selected[tempdata_selected["Country"] == cdata[1]]["AverageTemperature"]
                M = tempdata_selected[tempdata_selected["Country"] == cdata[0]]["AverageTemperature"]

                plt.subplots(figsize=(16, 10))
                plt.xlabel('Quarter', fontsize=15)
                plt.ylabel('Quarterly Rainfall (in mm)', fontsize=15)
                plt.title('Quarterly Rainfall in Tamilnadu,Delhi and Mumbai', fontsize=20)
                X = np.arange(6)
                bar1 = plt.bar(0.00, T, color='g', width=0.25)
                bar2 = plt.bar(0.25, D, color='b', width=0.25)
                bar3 = plt.bar(0.50, M, color='orange', width=0.25)

                plt.legend((bar1, bar2, bar3), ('Tamilnadu', 'Delhi', 'Mumbai'))
                plt.grid()
                # plt.xticks(X+0.25,['1900','1920','1940','1960','1980','2000'])
                plt.show()
            else:
                sns.distplot(tr_avg_temps)
                sns.distplot(us_avg_temps)
                sns.distplot(br_avg_temps)

                cdata = tempdata_selected["Country"].unique()
                for c in cdata:
                    sns.distplot(tempdata_selected[tempdata_selected["Country"] == c]["AverageTemperature"])

                sns.set_style("whitegrid")
                plt.legend(['Mumbai','Delhi','Tamilnadu'])
                plt.figure(figsize=(15, 5))

                for c in cdata:
                    sns.distplot(tempdata_selected[tempdata_selected["Country"] == c]["AverageTemperature"])

                plt.legend(cdata)

                sns.set_style("whitegrid")
                plt.figure(figsize=(15, 5))
                color = ["green", "blue", "orange"]

                for color, c in zip(color, cdata):
                    sns.distplot(tempdata_selected[tempdata_selected["Country"] == c]["AverageTemperature"])
                    cmean = tempdata_selected[tempdata_selected["Country"] == c]["AverageTemperature"].mean()
                    plt.vlines(cmean, 0, 0.16, color=color)

                plt.legend(cdata)

                tempdata_selected.columns[1:3]

                colv = tempdata_selected.columns[1:3]
                cdata = tempdata_selected["Country"].unique()
                plt.figure(figsize=(15, 5))

                for col in colv:
                    plt.figure(figsize=(15, 5))
                    for c in cdata:
                        sns.distplot(tempdata_selected[tempdata_selected["Country"] == c][col])
                    plt.legend(['Mumbai','Delhi','Tamilnadu'])
                    plt.show()

                trData = tempdata_selected[(tempdata_selected["Country"] == "Mumbai") & (tempdata_selected["dt"] > "01.01.1900")]
                

                trData_mean = trData.groupby(trData["dt"].dt.to_period("Y")).mean()
                trData_mean = trData_mean.reset_index()
                
                trData_mean["dt"] = trData_mean["dt"].astype("string").astype("datetime64")
                plt.figure(figsize=(15, 5))

                sns.lineplot(x="dt", y="AverageTemperature", data=trData_mean,color='b')
                plt.legend(['Mumbai'])
                
                trData = tempdata_selected[(tempdata_selected["Country"] == "Delhi") & (tempdata_selected["dt"] > "01.01.1900")]
                

                trData_mean = trData.groupby(trData["dt"].dt.to_period("Y")).mean()
                trData_mean = trData_mean.reset_index()
                
                trData_mean["dt"] = trData_mean["dt"].astype("string").astype("datetime64")
                plt.figure(figsize=(15, 5))

                sns.lineplot(x="dt", y="AverageTemperature", data=trData_mean,color='orange')
                plt.legend(['Delhi'])
                
                trData = tempdata_selected[(tempdata_selected["Country"] == "Tamilnadu") & (tempdata_selected["dt"] > "01.01.1900")]
                

                trData_mean = trData.groupby(trData["dt"].dt.to_period("Y")).mean()
                trData_mean = trData_mean.reset_index()
                
                trData_mean["dt"] = trData_mean["dt"].astype("string").astype("datetime64")
                plt.figure(figsize=(15, 5))

                sns.lineplot(x="dt", y="AverageTemperature", data=trData_mean,color='g')
                plt.legend(['Tamilnadu'])
                
                data_1900 = tempdata_selected[tempdata_selected["dt"] > "01.01.1900"]
                
                data_means = data_1900.groupby(["Country", data_1900["dt"].dt.to_period("Y")]).mean()
                data_means = data_means.reset_index()
                data_means["dt"] = data_means["dt"].astype("string").astype("datetime64")
                
                for column in data_means.columns[2:4]:
                    plt.figure(figsize=(15, 5))

                    for c in data_means["Country"].unique():
                        data = data_means[data_means["Country"] == c]
                        sns.lineplot(x="dt", y=col, data=data)
                    plt.legend(['Mumbai','Delhi','Tamilnadu'])

    elif inp1 == "month" or inp1 == "monthly":

        if inp2 == "rain" or inp2 == "rainfall":

            if inp3 == "bar" or inp3 == "barchart":
                # Average monthly rainfall in India
                ax = data[['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC']].mean()
                plt.subplots(figsize=(16, 10))
                plt.xlabel('Month', fontsize=30)
                plt.ylabel('Monthly Rainfall (in mm)', fontsize=30)
                plt.title('Monthly Rainfall in Subdivisions of India', fontsize=25)
                
               
                X = np.arange(11)
                bar1 = plt.bar(X + 0.00, ax, color='b', width=0.25)
                plt.legend(['Subdivisions'])
                plt.grid()
                plt.xticks(X + 0.25, ['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC'])
                plt.show()

                # Average monthly rainfall in Tamilnadu
                T = Tamilnadu[['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC']].mean()
                plt.subplots(figsize=(16, 10))
                plt.xlabel('Month', fontsize=30)
                plt.ylabel('Monthly Rainfall (in mm)', fontsize=30)
                plt.title('Monthly Rainfall in Tamilnadu', fontsize=25)
                
                X = np.arange(11)
                plt.bar(X + 0.00, T, color='lightgreen', width=0.25)
                

                plt.legend(['Tamilnadu'])
                plt.grid()
                plt.xticks(X + 0.25, ['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC'])
                plt.show()

                # Average monthly rainfall in Delhi
                D = Delhi[['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC']].mean()
                plt.subplots(figsize=(16, 10))
                plt.xlabel('Month', fontsize=30)
                plt.ylabel('Monthly Rainfall (in mm)', fontsize=30)
                plt.title('Monthly Rainfall in Delhi', fontsize=25)
                
                X = np.arange(11)
                
                bar2 = plt.bar(X + 0.25, D, color='violet', width=0.25)
                

                plt.legend(['Delhi'])
                plt.grid()
                plt.xticks(X + 0.25, ['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC'])
                plt.show()
                
                

                # Average monthly rainfall in Mumbai
                M = Mumbai[['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC']].mean()
                plt.subplots(figsize=(16, 10))
                plt.xlabel('Month', fontsize=30)
                plt.ylabel('Monthly Rainfall (in mm)', fontsize=30)
                plt.title('Monthly Rainfall in Mumbai', fontsize=25)
                
                X = np.arange(11)
                
                bar3 = plt.bar(X + 0.50, M, color='orange', width=0.25)

                plt.legend(['Mumbai'])
                plt.grid()
                plt.xticks(X + 0.25, ['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC'])
                plt.show()


                # Average monthly rainfall in Tamilnadu
                T = Tamilnadu[['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC']].mean()

                D = Delhi[['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC']].mean()

                M = Mumbai[['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC']].mean()

                plt.subplots(figsize=(16, 10))
                plt.xlabel('Quarter', fontsize=15)
                plt.ylabel('Quarterly Rainfall (in mm)', fontsize=15)
                plt.title('Quarterly Rainfall in Tamilnadu,Delhi and Mumbai', fontsize=20)
                X = np.arange(11)
                bar1 = plt.bar(X + 0.00, T, color='lightgreen', width=0.25)
                bar2 = plt.bar(X + 0.25, D, color='violet', width=0.25)
                bar3 = plt.bar(X + 0.50, M, color='orange', width=0.25)

                plt.legend((bar1, bar2, bar3), ('Tamilnadu', 'Delhi', 'Mumbai'))
                plt.grid()
                plt.xticks(X + 0.25, ['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC'])
                plt.show()
            else:
                print("No Data Found")
        elif inp2 == "temp" or inp2 == "temperature":
            if inp3 == "bar" or inp3 == "barchar":
                print("No Data Found")
            else:
                print("No Data Found")
# Out:
# please Enter 'Yearly' or 'Monthly' yearly
# What type of data you want about the Weather - 'Rain' or 'Temperature' rain
# What Type of Graph you Want - 'Line' or 'Barchart' bar
# Average annual rainfall received by Tamilnadu =  943 mm
# Average annual rainfall received by Arunachal Pradesh =  918 mm

# %%
    inp1 = input("please Enter 'Yearly' or 'Monthly' ")
    inp1.lower()
    inp2 = input("What type of data you want about the Weather - 'Rain' or 'Temperature' ")
    inp2.lower()
    inp3 = input("What Type of Graph you Want - 'Line' or 'Barchart' ")
    inp3.lower()
    if inp1 == "year" or inp1 == "yearly":
        if inp2 == "rain" or inp2 == "rainfall":
            if inp3 == "bar" or inp3 == "barchart":

                data[['SUBDIVISION', 'ANNUAL']].sort_values(by='ANNUAL', ascending=False).head(20)



                # Average monthly rainfall in India
                ax = data[['Jan-Feb', 'Mar-May', 'Jun-Sep', 'Oct-Dec']].mean().plot.bar(width=0.5, linewidth=2,
                                                                                        figsize=(16, 10))
                plt.xlabel('Quarter', fontsize=15)
                plt.ylabel('Quarterly Rainfall (in mm)', fontsize=15)
                plt.title('Quarterly Rainfall in India', fontsize=20)
                plt.legend(['Subdivisions'])
                ax.tick_params(labelsize=15)
                plt.grid()
                plt.show()



                # Getting rainfall data for Tamilnadu
                Tamilnadu = data.loc[((data['SUBDIVISION'] == 'TAMIL NADU'))]



                # Average monthly rainfall in Tamilnadu
                TM = Tamilnadu[['Jan-Feb', 'Mar-May', 'Jun-Sep', 'Oct-Dec']].mean().plot.bar(width=0.5, linewidth=2,
                                                                                             figsize=(16, 10),
                                                                                             color='lightgreen')
                plt.xlabel('Quarter', fontsize=15)
                plt.ylabel('Quarterly Rainfall (in mm)', fontsize=15)
                plt.title('Quarterly Rainfall in Tamilnadu', fontsize=20)
                plt.legend(['Tamilnadu'])
                TM.tick_params(labelsize=15)
                plt.grid()
                plt.show()



                print('Average annual rainfall received by Tamilnadu = ', int(Tamilnadu['ANNUAL'].mean()), 'mm')
                a = Tamilnadu[Tamilnadu['YEAR'] == 1917]

                # Getting rainfall data for Delhi
                Delhi = data.loc[(data['SUBDIVISION'] == 'DELHI')]



                # Average monthly rainfall in Arunachal Pradesh
                DM = Delhi[['Jan-Feb', 'Mar-May', 'Jun-Sep', 'Oct-Dec']].mean().plot.bar(width=0.5, linewidth=2,
                                                                                         figsize=(16, 10),
                                                                                         color="violet")
                plt.xlabel('Quarter', fontsize=15)
                plt.ylabel('Quarterly Rainfall (in mm)', fontsize=15)
                plt.title('Quarterly Rainfall in Delhi', fontsize=20)
                plt.legend(['Delhi'])
                DM.tick_params(labelsize=15)
                plt.grid()
                plt.show()



                print('Average annual rainfall received by Arunachal Pradesh = ', int(Delhi['ANNUAL'].mean()), 'mm')
                a = Delhi[Delhi['YEAR'] == 1948]

                # Getting rainfall data for Mumbai
                Mumbai = data.loc[(data['SUBDIVISION'] == 'MUMBAI')]



                # Average monthly rainfall in mumbai
                MM = Mumbai[['Jan-Feb', 'Mar-May', 'Jun-Sep', 'Oct-Dec']].mean().plot.bar(width=0.5, linewidth=2,
                                                                                          figsize=(16, 10),
                                                                                          color="orange")
                plt.xlabel('Quarter', fontsize=15)
                plt.ylabel('Quarterly Rainfall (in mm)', fontsize=15)
                plt.title('Quarterly Rainfall in Mumbai', fontsize=20)
                plt.legend(['Mumbai'])
                MM.tick_params(labelsize=15)
                plt.grid()
                plt.show()



                # Average monthly rainfall in t,M,D

                DM = Delhi[['Jan-Feb', 'Mar-May', 'Jun-Sep', 'Oct-Dec']].mean()

                TM = Tamilnadu[['Jan-Feb', 'Mar-May', 'Jun-Sep', 'Oct-Dec']].mean()
                MM = Mumbai[['Jan-Feb', 'Mar-May', 'Jun-Sep', 'Oct-Dec']].mean()

                plt.subplots(figsize=(16, 10))
                plt.xlabel('Quarter', fontsize=15)
                plt.ylabel('Quarterly Rainfall (in mm)', fontsize=15)
                plt.title('Quarterly Rainfall in Tamilnadu,Delhi and Mumbai', fontsize=20)
                X = np.arange(4)
                bar1 = plt.bar(X + 0.00, TM, color='lightgreen', width=0.25)
                bar2 = plt.bar(X + 0.25, DM, color='violet', width=0.25)
                bar3 = plt.bar(X + 0.50, MM, color='orange', width=0.25)

                plt.legend((bar1, bar2, bar3), ('Tamilnadu', 'Delhi', 'Mumbai'))
                plt.grid()
                plt.xticks(X + 0.25, ['Jan-Feb', 'Mar-May', 'Jun-Sep', 'Oct-Dec'])
                plt.show()




            else:
                
                # Visualizing annual rainfall over the years(1901-2015) in India
                ax = data.groupby("YEAR").mean()['ANNUAL'].plot(ylim=(1000, 2000), color='r', marker='o', linestyle='-',linewidth=2, figsize=(12, 10));
                plt.xlabel('Year', fontsize=20)
                plt.ylabel('Annual Rainfall (in mm)', fontsize=20)
                plt.title('Annual Rainfall from Year 1901 to 2015 in India', fontsize=25)
                plt.legend(['India'])
                ax.tick_params(labelsize=15)
                plt.grid()
                plt.show()
                

                # Visualizing annual rainfall over the years(1901-2015) in Tamilnadu
                TY = Tamilnadu.groupby("YEAR").mean()['ANNUAL'].plot(ylim=(50, 1500), color='green', marker='o',
                                                                     linestyle='-', linewidth=2, figsize=(12, 10));
                plt.xlabel('Year', fontsize=20)
                plt.ylabel('Tamilnadu Annual Rainfall (in mm)', fontsize=20)
                plt.title('Tamilnadu Annual Rainfall from Year 1901 to 2015', fontsize=25)
                plt.legend(['Tamilnadu'])
                TY.tick_params(labelsize=15)
                plt.grid()
                plt.show()

                # Visualizing annual rainfall over the years(1901-2015) in delhi
                DY = Delhi.groupby("YEAR").mean()['ANNUAL'].plot(ylim=(50, 6500), color='violet', marker='o',
                                                                 linestyle='-', linewidth=2, figsize=(12, 10));
                plt.xlabel('Year', fontsize=20)
                plt.ylabel('Delhi Annual Rainfall (in mm)', fontsize=20)
                plt.title('Delhi Annual Rainfall from Year 1901 to 2015', fontsize=25)
                plt.legend(['Delhi'])
                DY.tick_params(labelsize=15)
                plt.grid()
                plt.show()

                # Visualizing annual rainfall over the years(1901-2015) in mumbai
                MY = Mumbai.groupby("YEAR").mean()['ANNUAL'].plot(ylim=(1500, 6500), color='orange', marker='o',
                                                                  linestyle='-', linewidth=2, figsize=(12, 10));
                plt.xlabel('Year', fontsize=20)
                plt.ylabel('Mumbai Annual Rainfall (in mm)', fontsize=20)
                plt.title('Mumbai Annual Rainfall from Year 1901 to 2015', fontsize=25)
                plt.legend(['Mumbai'])
                ax.tick_params(labelsize=15)
                plt.grid()
                plt.show()

                # Visualizing annual rainfall over the years(1901-2015) in t,m,d
                TY = Tamilnadu.groupby("YEAR").mean()['ANNUAL'].plot(ylim=(50, 7000), color='green', marker='o',
                                                                     linestyle='-', linewidth=2, figsize=(12, 10));
                DY = Delhi.groupby("YEAR").mean()['ANNUAL'].plot(ylim=(50, 7000), color='violet', marker='o',
                                                                 linestyle='-', linewidth=2, figsize=(12, 10));

                MY = Mumbai.groupby("YEAR").mean()['ANNUAL'].plot(ylim=(50, 7000), color='orange', marker='o',
                                                                  linestyle='-', linewidth=2, figsize=(12, 10));
                plt.xlabel('Year', fontsize=20)
                plt.ylabel('T,D,and M Annual Rainfall (in mm)', fontsize=20)
                plt.title(' T,D,and M Annual Rainfall from Year 1901 to 2015', fontsize=25)
                plt.legend(['Tamilnadu', 'Delhi', 'Mumbai'])
                TY.tick_params(labelsize=15)
                DY.tick_params(labelsize=15)
                MY.tick_params(labelsize=15)
                plt.grid()
                plt.show()
                
                 # Visualizing annual rainfall over the years(1901-2015) in India
                ax = data.groupby("YEAR").mean()['ANNUAL'].plot(ylim=(1000, 2000), color='r', linestyle='-',linewidth=2, figsize=(12, 10));
                plt.xlabel('Year', fontsize=20)
                plt.ylabel('Annual Rainfall (in mm)', fontsize=20)
                plt.title('Annual Rainfall from Year 1901 to 2015 in India', fontsize=25)
                plt.legend(['India'])
                ax.tick_params(labelsize=15)
                plt.grid()
                plt.show()
                

                # Visualizing annual rainfall over the years(1901-2015) in Tamilnadu
                TY = Tamilnadu.groupby("YEAR").mean()['ANNUAL'].plot(ylim=(50, 1500), color='green',
                                                                     linestyle='-', linewidth=2, figsize=(12, 10));
                plt.xlabel('Year', fontsize=20)
                plt.ylabel('Tamilnadu Annual Rainfall (in mm)', fontsize=20)
                plt.title('Tamilnadu Annual Rainfall from Year 1901 to 2015', fontsize=25)
                plt.legend(['Tamilnadu'])
                TY.tick_params(labelsize=15)
                plt.grid()
                plt.show()

                # Visualizing annual rainfall over the years(1901-2015) in delhi
                DY = Delhi.groupby("YEAR").mean()['ANNUAL'].plot(ylim=(50, 6500), color='violet',
                                                                 linestyle='-', linewidth=2, figsize=(12, 10));
                plt.xlabel('Year', fontsize=20)
                plt.ylabel('Delhi Annual Rainfall (in mm)', fontsize=20)
                plt.title('Delhi Annual Rainfall from Year 1901 to 2015', fontsize=25)
                plt.legend(['Delhi'])
                DY.tick_params(labelsize=15)
                plt.grid()
                plt.show()

                # Visualizing annual rainfall over the years(1901-2015) in mumbai
                MY = Mumbai.groupby("YEAR").mean()['ANNUAL'].plot(ylim=(1500, 6500), color='orange',
                                                                  linestyle='-', linewidth=2, figsize=(12, 10));
                plt.xlabel('Year', fontsize=20)
                plt.ylabel('Mumbai Annual Rainfall (in mm)', fontsize=20)
                plt.title('Mumbai Annual Rainfall from Year 1901 to 2015', fontsize=25)
                plt.legend(['Mumbai'])
                ax.tick_params(labelsize=15)
                plt.grid()
                plt.show()

                # Visualizing annual rainfall over the years(1901-2015) in t,d,m
                TY = Tamilnadu.groupby("YEAR").mean()['ANNUAL'].plot(ylim=(50, 7000), color='green',
                                                                     linestyle='-', linewidth=2, figsize=(12, 10));
                DY = Delhi.groupby("YEAR").mean()['ANNUAL'].plot(ylim=(50, 7000), color='violet',
                                                                 linestyle='-', linewidth=2, figsize=(12, 10));

                MY = Mumbai.groupby("YEAR").mean()['ANNUAL'].plot(ylim=(50, 7000), color='orange',
                                                                  linestyle='-', linewidth=2, figsize=(12, 10));
                plt.xlabel('Year', fontsize=20)
                plt.ylabel('T,D,and M Annual Rainfall (in mm)', fontsize=20)
                plt.title('T,D,and M Annual Rainfall from Year 1901 to 2015', fontsize=25)
                plt.legend(['Tamilnadu', 'Delhi', 'Mumbai'])
                TY.tick_params(labelsize=15)
                DY.tick_params(labelsize=15)
                MY.tick_params(labelsize=15)
                plt.grid()
                plt.show()
                
                tempdata_selected = data[data["SUBDIVISION"].isin(["MUMBAI", "DELHI", "TAMIL NADU"])]
                tr_avg_temps = tempdata_selected[tempdata_selected["SUBDIVISION"]=="MUMBAI"]["ANNUAL"]
                br_avg_temps = tempdata_selected[tempdata_selected["SUBDIVISION"]=="DELHI"]["ANNUAL"]
                us_avg_temps = tempdata_selected[tempdata_selected["SUBDIVISION"]=="TAMIL NADU"]["ANNUAL"]
                plt.xlabel('Year', fontsize=10)
                plt.ylabel('T,D,and M Annual Rainfall (in mm)', fontsize=10)
                plt.title('T,D,and M Annual Rainfall from Year 1901 to 2015', fontsize=10)
                plt.legend(['Tamilnadu', 'Delhi', 'Mumbai'])
                sns.distplot(tr_avg_temps)
                sns.distplot(us_avg_temps)
                sns.distplot(br_avg_temps)
                plt.legend(['Tamilnadu', 'Delhi', 'Mumbai'])
                plt.show()

        elif inp2 == "temp" or inp2 == "temperature":
            if inp3 == "bar" or inp3 == "barchar":
                T = tempdata_selected[tempdata_selected["Country"] == cdata[2]]["AverageTemperature"]
                D = tempdata_selected[tempdata_selected["Country"] == cdata[1]]["AverageTemperature"]
                M = tempdata_selected[tempdata_selected["Country"] == cdata[0]]["AverageTemperature"]

                plt.subplots(figsize=(16, 10))
                plt.xlabel('Quarter', fontsize=15)
                plt.ylabel('Quarterly Rainfall (in mm)', fontsize=15)
                plt.title('Quarterly Rainfall in Tamilnadu,Delhi and Mumbai', fontsize=20)
                X = np.arange(6)
                bar1 = plt.bar(0.00, T, color='g', width=0.25)
                bar2 = plt.bar(0.25, D, color='b', width=0.25)
                bar3 = plt.bar(0.50, M, color='orange', width=0.25)

                plt.legend((bar1, bar2, bar3), ('Tamilnadu', 'Delhi', 'Mumbai'))
                plt.grid()
                # plt.xticks(X+0.25,['1900','1920','1940','1960','1980','2000'])
                plt.show()
            else:
                sns.distplot(tr_avg_temps)
                sns.distplot(us_avg_temps)
                sns.distplot(br_avg_temps)

                cdata = tempdata_selected["Country"].unique()
                for c in cdata:
                    sns.distplot(tempdata_selected[tempdata_selected["Country"] == c]["AverageTemperature"])

                sns.set_style("whitegrid")
                plt.legend(['Mumbai','Delhi','Tamilnadu'])
                plt.figure(figsize=(15, 5))

                for c in cdata:
                    sns.distplot(tempdata_selected[tempdata_selected["Country"] == c]["AverageTemperature"])

                plt.legend(cdata)

                sns.set_style("whitegrid")
                plt.figure(figsize=(15, 5))
                color = ["green", "blue", "orange"]

                for color, c in zip(color, cdata):
                    sns.distplot(tempdata_selected[tempdata_selected["Country"] == c]["AverageTemperature"])
                    cmean = tempdata_selected[tempdata_selected["Country"] == c]["AverageTemperature"].mean()
                    plt.vlines(cmean, 0, 0.16, color=color)

                plt.legend(cdata)

                tempdata_selected.columns[1:3]

                colv = tempdata_selected.columns[1:3]
                cdata = tempdata_selected["Country"].unique()
                plt.figure(figsize=(15, 5))

                for col in colv:
                    plt.figure(figsize=(15, 5))
                    for c in cdata:
                        sns.distplot(tempdata_selected[tempdata_selected["Country"] == c][col])
                    plt.legend(['Mumbai','Delhi','Tamilnadu'])
                    plt.show()

                trData = tempdata_selected[(tempdata_selected["Country"] == "Mumbai") & (tempdata_selected["dt"] > "01.01.1900")]
                

                trData_mean = trData.groupby(trData["dt"].dt.to_period("Y")).mean()
                trData_mean = trData_mean.reset_index()
                
                trData_mean["dt"] = trData_mean["dt"].astype("string").astype("datetime64")
                plt.figure(figsize=(15, 5))

                sns.lineplot(x="dt", y="AverageTemperature", data=trData_mean,color='b')
                plt.legend(['Mumbai'])
                
                trData = tempdata_selected[(tempdata_selected["Country"] == "Delhi") & (tempdata_selected["dt"] > "01.01.1900")]
                

                trData_mean = trData.groupby(trData["dt"].dt.to_period("Y")).mean()
                trData_mean = trData_mean.reset_index()
                
                trData_mean["dt"] = trData_mean["dt"].astype("string").astype("datetime64")
                plt.figure(figsize=(15, 5))

                sns.lineplot(x="dt", y="AverageTemperature", data=trData_mean,color='orange')
                plt.legend(['Delhi'])
                
                trData = tempdata_selected[(tempdata_selected["Country"] == "Tamilnadu") & (tempdata_selected["dt"] > "01.01.1900")]
                

                trData_mean = trData.groupby(trData["dt"].dt.to_period("Y")).mean()
                trData_mean = trData_mean.reset_index()
                
                trData_mean["dt"] = trData_mean["dt"].astype("string").astype("datetime64")
                plt.figure(figsize=(15, 5))

                sns.lineplot(x="dt", y="AverageTemperature", data=trData_mean,color='g')
                plt.legend(['Tamilnadu'])
                
                data_1900 = tempdata_selected[tempdata_selected["dt"] > "01.01.1900"]
                
                data_means = data_1900.groupby(["Country", data_1900["dt"].dt.to_period("Y")]).mean()
                data_means = data_means.reset_index()
                data_means["dt"] = data_means["dt"].astype("string").astype("datetime64")
                
                for column in data_means.columns[2:4]:
                    plt.figure(figsize=(15, 5))

                    for c in data_means["Country"].unique():
                        data = data_means[data_means["Country"] == c]
                        sns.lineplot(x="dt", y=col, data=data)
                    plt.legend(['Mumbai','Delhi','Tamilnadu'])

    elif inp1 == "month" or inp1 == "monthly":

        if inp2 == "rain" or inp2 == "rainfall":

            if inp3 == "bar" or inp3 == "barchart":
                # Average monthly rainfall in India
                ax = data[['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC']].mean()
                plt.subplots(figsize=(16, 10))
                plt.xlabel('Month', fontsize=30)
                plt.ylabel('Monthly Rainfall (in mm)', fontsize=30)
                plt.title('Monthly Rainfall in Subdivisions of India', fontsize=25)
                
               
                X = np.arange(11)
                bar1 = plt.bar(X + 0.00, ax, color='b', width=0.25)
                plt.legend(['Subdivisions'])
                plt.grid()
                plt.xticks(X + 0.25, ['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC'])
                plt.show()

                # Average monthly rainfall in Tamilnadu
                T = Tamilnadu[['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC']].mean()
                plt.subplots(figsize=(16, 10))
                plt.xlabel('Month', fontsize=30)
                plt.ylabel('Monthly Rainfall (in mm)', fontsize=30)
                plt.title('Monthly Rainfall in Tamilnadu', fontsize=25)
                
                X = np.arange(11)
                plt.bar(X + 0.00, T, color='lightgreen', width=0.25)
                

                plt.legend(['Tamilnadu'])
                plt.grid()
                plt.xticks(X + 0.25, ['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC'])
                plt.show()

                # Average monthly rainfall in Delhi
                D = Delhi[['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC']].mean()
                plt.subplots(figsize=(16, 10))
                plt.xlabel('Month', fontsize=30)
                plt.ylabel('Monthly Rainfall (in mm)', fontsize=30)
                plt.title('Monthly Rainfall in Delhi', fontsize=25)
                
                X = np.arange(11)
                
                bar2 = plt.bar(X + 0.25, D, color='violet', width=0.25)
                

                plt.legend(['Delhi'])
                plt.grid()
                plt.xticks(X + 0.25, ['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC'])
                plt.show()
                
                

                # Average monthly rainfall in Mumbai
                M = Mumbai[['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC']].mean()
                plt.subplots(figsize=(16, 10))
                plt.xlabel('Month', fontsize=30)
                plt.ylabel('Monthly Rainfall (in mm)', fontsize=30)
                plt.title('Monthly Rainfall in Mumbai', fontsize=25)
                
                X = np.arange(11)
                
                bar3 = plt.bar(X + 0.50, M, color='orange', width=0.25)

                plt.legend(['Mumbai'])
                plt.grid()
                plt.xticks(X + 0.25, ['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC'])
                plt.show()


                # Average monthly rainfall in Tamilnadu
                T = Tamilnadu[['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC']].mean()

                D = Delhi[['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC']].mean()

                M = Mumbai[['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC']].mean()

                plt.subplots(figsize=(16, 10))
                plt.xlabel('Quarter', fontsize=15)
                plt.ylabel('Quarterly Rainfall (in mm)', fontsize=15)
                plt.title('Quarterly Rainfall in Tamilnadu,Delhi and Mumbai', fontsize=20)
                X = np.arange(11)
                bar1 = plt.bar(X + 0.00, T, color='lightgreen', width=0.25)
                bar2 = plt.bar(X + 0.25, D, color='violet', width=0.25)
                bar3 = plt.bar(X + 0.50, M, color='orange', width=0.25)

                plt.legend((bar1, bar2, bar3), ('Tamilnadu', 'Delhi', 'Mumbai'))
                plt.grid()
                plt.xticks(X + 0.25, ['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC'])
                plt.show()
            else:
                print("No Data Found")
        elif inp2 == "temp" or inp2 == "temperature":
            if inp3 == "bar" or inp3 == "barchar":
                print("No Data Found")
            else:
                print("No Data Found")
# Out:
# please Enter 'Yearly' or 'Monthly' month
# What type of data you want about the Weather - 'Rain' or 'Temperature' rain
# What Type of Graph you Want - 'Line' or 'Barchart' bar

# %%
    inp1 = input("please Enter 'Yearly' or 'Monthly' ")
    inp1.lower()
    inp2 = input("What type of data you want about the Weather - 'Rain' or 'Temperature' ")
    inp2.lower()
    inp3 = input("What Type of Graph you Want - 'Line' or 'Barchart' ")
    inp3.lower()
    if inp1 == "year" or inp1 == "yearly":
        if inp2 == "rain" or inp2 == "rainfall":
            if inp3 == "bar" or inp3 == "barchart":

                data[['SUBDIVISION', 'ANNUAL']].sort_values(by='ANNUAL', ascending=False).head(20)



                # Average monthly rainfall in India
                ax = data[['Jan-Feb', 'Mar-May', 'Jun-Sep', 'Oct-Dec']].mean().plot.bar(width=0.5, linewidth=2,
                                                                                        figsize=(16, 10))
                plt.xlabel('Quarter', fontsize=15)
                plt.ylabel('Quarterly Rainfall (in mm)', fontsize=15)
                plt.title('Quarterly Rainfall in India', fontsize=20)
                plt.legend(['Subdivisions'])
                ax.tick_params(labelsize=15)
                plt.grid()
                plt.show()



                # Getting rainfall data for Tamilnadu
                Tamilnadu = data.loc[((data['SUBDIVISION'] == 'TAMIL NADU'))]



                # Average monthly rainfall in Tamilnadu
                TM = Tamilnadu[['Jan-Feb', 'Mar-May', 'Jun-Sep', 'Oct-Dec']].mean().plot.bar(width=0.5, linewidth=2,
                                                                                             figsize=(16, 10),
                                                                                             color='lightgreen')
                plt.xlabel('Quarter', fontsize=15)
                plt.ylabel('Quarterly Rainfall (in mm)', fontsize=15)
                plt.title('Quarterly Rainfall in Tamilnadu', fontsize=20)
                plt.legend(['Tamilnadu'])
                TM.tick_params(labelsize=15)
                plt.grid()
                plt.show()



                print('Average annual rainfall received by Tamilnadu = ', int(Tamilnadu['ANNUAL'].mean()), 'mm')
                a = Tamilnadu[Tamilnadu['YEAR'] == 1917]

                # Getting rainfall data for Delhi
                Delhi = data.loc[(data['SUBDIVISION'] == 'DELHI')]



                # Average monthly rainfall in Arunachal Pradesh
                DM = Delhi[['Jan-Feb', 'Mar-May', 'Jun-Sep', 'Oct-Dec']].mean().plot.bar(width=0.5, linewidth=2,
                                                                                         figsize=(16, 10),
                                                                                         color="violet")
                plt.xlabel('Quarter', fontsize=15)
                plt.ylabel('Quarterly Rainfall (in mm)', fontsize=15)
                plt.title('Quarterly Rainfall in Delhi', fontsize=20)
                plt.legend(['Delhi'])
                DM.tick_params(labelsize=15)
                plt.grid()
                plt.show()



                print('Average annual rainfall received by Arunachal Pradesh = ', int(Delhi['ANNUAL'].mean()), 'mm')
                a = Delhi[Delhi['YEAR'] == 1948]

                # Getting rainfall data for Mumbai
                Mumbai = data.loc[(data['SUBDIVISION'] == 'MUMBAI')]



                # Average monthly rainfall in mumbai
                MM = Mumbai[['Jan-Feb', 'Mar-May', 'Jun-Sep', 'Oct-Dec']].mean().plot.bar(width=0.5, linewidth=2,
                                                                                          figsize=(16, 10),
                                                                                          color="orange")
                plt.xlabel('Quarter', fontsize=15)
                plt.ylabel('Quarterly Rainfall (in mm)', fontsize=15)
                plt.title('Quarterly Rainfall in Mumbai', fontsize=20)
                plt.legend(['Mumbai'])
                MM.tick_params(labelsize=15)
                plt.grid()
                plt.show()



                # Average monthly rainfall in t,M,D

                DM = Delhi[['Jan-Feb', 'Mar-May', 'Jun-Sep', 'Oct-Dec']].mean()

                TM = Tamilnadu[['Jan-Feb', 'Mar-May', 'Jun-Sep', 'Oct-Dec']].mean()
                MM = Mumbai[['Jan-Feb', 'Mar-May', 'Jun-Sep', 'Oct-Dec']].mean()

                plt.subplots(figsize=(16, 10))
                plt.xlabel('Quarter', fontsize=15)
                plt.ylabel('Quarterly Rainfall (in mm)', fontsize=15)
                plt.title('Quarterly Rainfall in Tamilnadu,Delhi and Mumbai', fontsize=20)
                X = np.arange(4)
                bar1 = plt.bar(X + 0.00, TM, color='lightgreen', width=0.25)
                bar2 = plt.bar(X + 0.25, DM, color='violet', width=0.25)
                bar3 = plt.bar(X + 0.50, MM, color='orange', width=0.25)

                plt.legend((bar1, bar2, bar3), ('Tamilnadu', 'Delhi', 'Mumbai'))
                plt.grid()
                plt.xticks(X + 0.25, ['Jan-Feb', 'Mar-May', 'Jun-Sep', 'Oct-Dec'])
                plt.show()




            else:
                
                # Visualizing annual rainfall over the years(1901-2015) in India
                ax = data.groupby("YEAR").mean()['ANNUAL'].plot(ylim=(1000, 2000), color='r', marker='o', linestyle='-',linewidth=2, figsize=(12, 10));
                plt.xlabel('Year', fontsize=20)
                plt.ylabel('Annual Rainfall (in mm)', fontsize=20)
                plt.title('Annual Rainfall from Year 1901 to 2015 in India', fontsize=25)
                plt.legend(['India'])
                ax.tick_params(labelsize=15)
                plt.grid()
                plt.show()
                

                # Visualizing annual rainfall over the years(1901-2015) in Tamilnadu
                TY = Tamilnadu.groupby("YEAR").mean()['ANNUAL'].plot(ylim=(50, 1500), color='green', marker='o',
                                                                     linestyle='-', linewidth=2, figsize=(12, 10));
                plt.xlabel('Year', fontsize=20)
                plt.ylabel('Tamilnadu Annual Rainfall (in mm)', fontsize=20)
                plt.title('Tamilnadu Annual Rainfall from Year 1901 to 2015', fontsize=25)
                plt.legend(['Tamilnadu'])
                TY.tick_params(labelsize=15)
                plt.grid()
                plt.show()

                # Visualizing annual rainfall over the years(1901-2015) in delhi
                DY = Delhi.groupby("YEAR").mean()['ANNUAL'].plot(ylim=(50, 6500), color='violet', marker='o',
                                                                 linestyle='-', linewidth=2, figsize=(12, 10));
                plt.xlabel('Year', fontsize=20)
                plt.ylabel('Delhi Annual Rainfall (in mm)', fontsize=20)
                plt.title('Delhi Annual Rainfall from Year 1901 to 2015', fontsize=25)
                plt.legend(['Delhi'])
                DY.tick_params(labelsize=15)
                plt.grid()
                plt.show()

                # Visualizing annual rainfall over the years(1901-2015) in mumbai
                MY = Mumbai.groupby("YEAR").mean()['ANNUAL'].plot(ylim=(1500, 6500), color='orange', marker='o',
                                                                  linestyle='-', linewidth=2, figsize=(12, 10));
                plt.xlabel('Year', fontsize=20)
                plt.ylabel('Mumbai Annual Rainfall (in mm)', fontsize=20)
                plt.title('Mumbai Annual Rainfall from Year 1901 to 2015', fontsize=25)
                plt.legend(['Mumbai'])
                ax.tick_params(labelsize=15)
                plt.grid()
                plt.show()

                # Visualizing annual rainfall over the years(1901-2015) in t,m,d
                TY = Tamilnadu.groupby("YEAR").mean()['ANNUAL'].plot(ylim=(50, 7000), color='green', marker='o',
                                                                     linestyle='-', linewidth=2, figsize=(12, 10));
                DY = Delhi.groupby("YEAR").mean()['ANNUAL'].plot(ylim=(50, 7000), color='violet', marker='o',
                                                                 linestyle='-', linewidth=2, figsize=(12, 10));

                MY = Mumbai.groupby("YEAR").mean()['ANNUAL'].plot(ylim=(50, 7000), color='orange', marker='o',
                                                                  linestyle='-', linewidth=2, figsize=(12, 10));
                plt.xlabel('Year', fontsize=20)
                plt.ylabel('T,D,and M Annual Rainfall (in mm)', fontsize=20)
                plt.title(' T,D,and M Annual Rainfall from Year 1901 to 2015', fontsize=25)
                plt.legend(['Tamilnadu', 'Delhi', 'Mumbai'])
                TY.tick_params(labelsize=15)
                DY.tick_params(labelsize=15)
                MY.tick_params(labelsize=15)
                plt.grid()
                plt.show()
                
                 # Visualizing annual rainfall over the years(1901-2015) in India
                ax = data.groupby("YEAR").mean()['ANNUAL'].plot(ylim=(1000, 2000), color='r', linestyle='-',linewidth=2, figsize=(12, 10));
                plt.xlabel('Year', fontsize=20)
                plt.ylabel('Annual Rainfall (in mm)', fontsize=20)
                plt.title('Annual Rainfall from Year 1901 to 2015 in India', fontsize=25)
                plt.legend(['India'])
                ax.tick_params(labelsize=15)
                plt.grid()
                plt.show()
                

                # Visualizing annual rainfall over the years(1901-2015) in Tamilnadu
                TY = Tamilnadu.groupby("YEAR").mean()['ANNUAL'].plot(ylim=(50, 1500), color='green',
                                                                     linestyle='-', linewidth=2, figsize=(12, 10));
                plt.xlabel('Year', fontsize=20)
                plt.ylabel('Tamilnadu Annual Rainfall (in mm)', fontsize=20)
                plt.title('Tamilnadu Annual Rainfall from Year 1901 to 2015', fontsize=25)
                plt.legend(['Tamilnadu'])
                TY.tick_params(labelsize=15)
                plt.grid()
                plt.show()

                # Visualizing annual rainfall over the years(1901-2015) in delhi
                DY = Delhi.groupby("YEAR").mean()['ANNUAL'].plot(ylim=(50, 6500), color='violet',
                                                                 linestyle='-', linewidth=2, figsize=(12, 10));
                plt.xlabel('Year', fontsize=20)
                plt.ylabel('Delhi Annual Rainfall (in mm)', fontsize=20)
                plt.title('Delhi Annual Rainfall from Year 1901 to 2015', fontsize=25)
                plt.legend(['Delhi'])
                DY.tick_params(labelsize=15)
                plt.grid()
                plt.show()

                # Visualizing annual rainfall over the years(1901-2015) in mumbai
                MY = Mumbai.groupby("YEAR").mean()['ANNUAL'].plot(ylim=(1500, 6500), color='orange',
                                                                  linestyle='-', linewidth=2, figsize=(12, 10));
                plt.xlabel('Year', fontsize=20)
                plt.ylabel('Mumbai Annual Rainfall (in mm)', fontsize=20)
                plt.title('Mumbai Annual Rainfall from Year 1901 to 2015', fontsize=25)
                plt.legend(['Mumbai'])
                ax.tick_params(labelsize=15)
                plt.grid()
                plt.show()

                # Visualizing annual rainfall over the years(1901-2015) in t,d,m
                TY = Tamilnadu.groupby("YEAR").mean()['ANNUAL'].plot(ylim=(50, 7000), color='green',
                                                                     linestyle='-', linewidth=2, figsize=(12, 10));
                DY = Delhi.groupby("YEAR").mean()['ANNUAL'].plot(ylim=(50, 7000), color='violet',
                                                                 linestyle='-', linewidth=2, figsize=(12, 10));

                MY = Mumbai.groupby("YEAR").mean()['ANNUAL'].plot(ylim=(50, 7000), color='orange',
                                                                  linestyle='-', linewidth=2, figsize=(12, 10));
                plt.xlabel('Year', fontsize=20)
                plt.ylabel('T,D,and M Annual Rainfall (in mm)', fontsize=20)
                plt.title('T,D,and M Annual Rainfall from Year 1901 to 2015', fontsize=25)
                plt.legend(['Tamilnadu', 'Delhi', 'Mumbai'])
                TY.tick_params(labelsize=15)
                DY.tick_params(labelsize=15)
                MY.tick_params(labelsize=15)
                plt.grid()
                plt.show()
                
                tempdata_selected = data[data["SUBDIVISION"].isin(["MUMBAI", "DELHI", "TAMIL NADU"])]
                tr_avg_temps = tempdata_selected[tempdata_selected["SUBDIVISION"]=="MUMBAI"]["ANNUAL"]
                br_avg_temps = tempdata_selected[tempdata_selected["SUBDIVISION"]=="DELHI"]["ANNUAL"]
                us_avg_temps = tempdata_selected[tempdata_selected["SUBDIVISION"]=="TAMIL NADU"]["ANNUAL"]
                plt.xlabel('Year', fontsize=10)
                plt.ylabel('T,D,and M Annual Rainfall (in mm)', fontsize=10)
                plt.title('T,D,and M Annual Rainfall from Year 1901 to 2015', fontsize=10)
                plt.legend(['Tamilnadu', 'Delhi', 'Mumbai'])
                sns.distplot(tr_avg_temps)
                sns.distplot(us_avg_temps)
                sns.distplot(br_avg_temps)
                plt.legend(['Tamilnadu', 'Delhi', 'Mumbai'])
                plt.show()

        elif inp2 == "temp" or inp2 == "temperature":
            if inp3 == "bar" or inp3 == "barchar":
                T = tempdata_selected[tempdata_selected["Country"] == cdata[2]]["AverageTemperature"]
                D = tempdata_selected[tempdata_selected["Country"] == cdata[1]]["AverageTemperature"]
                M = tempdata_selected[tempdata_selected["Country"] == cdata[0]]["AverageTemperature"]

                plt.subplots(figsize=(16, 10))
                plt.xlabel('Quarter', fontsize=15)
                plt.ylabel('Quarterly Rainfall (in mm)', fontsize=15)
                plt.title('Quarterly Rainfall in Tamilnadu,Delhi and Mumbai', fontsize=20)
                X = np.arange(6)
                bar1 = plt.bar(0.00, T, color='g', width=0.25)
                bar2 = plt.bar(0.25, D, color='b', width=0.25)
                bar3 = plt.bar(0.50, M, color='orange', width=0.25)

                plt.legend((bar1, bar2, bar3), ('Tamilnadu', 'Delhi', 'Mumbai'))
                plt.grid()
                # plt.xticks(X+0.25,['1900','1920','1940','1960','1980','2000'])
                plt.show()
            else:
                sns.distplot(tr_avg_temps)
                sns.distplot(us_avg_temps)
                sns.distplot(br_avg_temps)

                cdata = tempdata_selected["Country"].unique()
                for c in cdata:
                    sns.distplot(tempdata_selected[tempdata_selected["Country"] == c]["AverageTemperature"])

                sns.set_style("whitegrid")
                plt.legend(['Mumbai','Delhi','Tamilnadu'])
                plt.figure(figsize=(15, 5))

                for c in cdata:
                    sns.distplot(tempdata_selected[tempdata_selected["Country"] == c]["AverageTemperature"])

                plt.legend(cdata)

                sns.set_style("whitegrid")
                plt.figure(figsize=(15, 5))
                color = ["green", "blue", "orange"]

                for color, c in zip(color, cdata):
                    sns.distplot(tempdata_selected[tempdata_selected["Country"] == c]["AverageTemperature"])
                    cmean = tempdata_selected[tempdata_selected["Country"] == c]["AverageTemperature"].mean()
                    plt.vlines(cmean, 0, 0.16, color=color)

                plt.legend(cdata)

                tempdata_selected.columns[1:3]

                colv = tempdata_selected.columns[1:3]
                cdata = tempdata_selected["Country"].unique()
                plt.figure(figsize=(15, 5))

                for col in colv:
                    plt.figure(figsize=(15, 5))
                    for c in cdata:
                        sns.distplot(tempdata_selected[tempdata_selected["Country"] == c][col])
                    plt.legend(['Mumbai','Delhi','Tamilnadu'])
                    plt.show()

                trData = tempdata_selected[(tempdata_selected["Country"] == "Mumbai") & (tempdata_selected["dt"] > "01.01.1900")]
                

                trData_mean = trData.groupby(trData["dt"].dt.to_period("Y")).mean()
                trData_mean = trData_mean.reset_index()
                
                trData_mean["dt"] = trData_mean["dt"].astype("string").astype("datetime64")
                plt.figure(figsize=(15, 5))

                sns.lineplot(x="dt", y="AverageTemperature", data=trData_mean,color='b')
                plt.legend(['Mumbai'])
                
                trData = tempdata_selected[(tempdata_selected["Country"] == "Delhi") & (tempdata_selected["dt"] > "01.01.1900")]
                

                trData_mean = trData.groupby(trData["dt"].dt.to_period("Y")).mean()
                trData_mean = trData_mean.reset_index()
                
                trData_mean["dt"] = trData_mean["dt"].astype("string").astype("datetime64")
                plt.figure(figsize=(15, 5))

                sns.lineplot(x="dt", y="AverageTemperature", data=trData_mean,color='orange')
                plt.legend(['Delhi'])
                
                trData = tempdata_selected[(tempdata_selected["Country"] == "Tamilnadu") & (tempdata_selected["dt"] > "01.01.1900")]
                

                trData_mean = trData.groupby(trData["dt"].dt.to_period("Y")).mean()
                trData_mean = trData_mean.reset_index()
                
                trData_mean["dt"] = trData_mean["dt"].astype("string").astype("datetime64")
                plt.figure(figsize=(15, 5))

                sns.lineplot(x="dt", y="AverageTemperature", data=trData_mean,color='g')
                plt.legend(['Tamilnadu'])
                
                data_1900 = tempdata_selected[tempdata_selected["dt"] > "01.01.1900"]
                
                data_means = data_1900.groupby(["Country", data_1900["dt"].dt.to_period("Y")]).mean()
                data_means = data_means.reset_index()
                data_means["dt"] = data_means["dt"].astype("string").astype("datetime64")
                
                for column in data_means.columns[2:4]:
                    plt.figure(figsize=(15, 5))

                    for c in data_means["Country"].unique():
                        data = data_means[data_means["Country"] == c]
                        sns.lineplot(x="dt", y=col, data=data)
                    plt.legend(['Mumbai','Delhi','Tamilnadu'])

    elif inp1 == "month" or inp1 == "monthly":

        if inp2 == "rain" or inp2 == "rainfall":

            if inp3 == "bar" or inp3 == "barchart":
                # Average monthly rainfall in India
                ax = data[['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC']].mean()
                plt.subplots(figsize=(16, 10))
                plt.xlabel('Month', fontsize=30)
                plt.ylabel('Monthly Rainfall (in mm)', fontsize=30)
                plt.title('Monthly Rainfall in Subdivisions of India', fontsize=25)
                
               
                X = np.arange(11)
                bar1 = plt.bar(X + 0.00, ax, color='b', width=0.25)
                plt.legend(['Subdivisions'])
                plt.grid()
                plt.xticks(X + 0.25, ['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC'])
                plt.show()

                # Average monthly rainfall in Tamilnadu
                T = Tamilnadu[['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC']].mean()
                plt.subplots(figsize=(16, 10))
                plt.xlabel('Month', fontsize=30)
                plt.ylabel('Monthly Rainfall (in mm)', fontsize=30)
                plt.title('Monthly Rainfall in Tamilnadu', fontsize=25)
                
                X = np.arange(11)
                plt.bar(X + 0.00, T, color='lightgreen', width=0.25)
                

                plt.legend(['Tamilnadu'])
                plt.grid()
                plt.xticks(X + 0.25, ['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC'])
                plt.show()

                # Average monthly rainfall in Delhi
                D = Delhi[['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC']].mean()
                plt.subplots(figsize=(16, 10))
                plt.xlabel('Month', fontsize=30)
                plt.ylabel('Monthly Rainfall (in mm)', fontsize=30)
                plt.title('Monthly Rainfall in Delhi', fontsize=25)
                
                X = np.arange(11)
                
                bar2 = plt.bar(X + 0.25, D, color='violet', width=0.25)
                

                plt.legend(['Delhi'])
                plt.grid()
                plt.xticks(X + 0.25, ['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC'])
                plt.show()
                
                

                # Average monthly rainfall in Mumbai
                M = Mumbai[['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC']].mean()
                plt.subplots(figsize=(16, 10))
                plt.xlabel('Month', fontsize=30)
                plt.ylabel('Monthly Rainfall (in mm)', fontsize=30)
                plt.title('Monthly Rainfall in Mumbai', fontsize=25)
                
                X = np.arange(11)
                
                bar3 = plt.bar(X + 0.50, M, color='orange', width=0.25)

                plt.legend(['Mumbai'])
                plt.grid()
                plt.xticks(X + 0.25, ['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC'])
                plt.show()


                # Average monthly rainfall in Tamilnadu
                T = Tamilnadu[['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC']].mean()

                D = Delhi[['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC']].mean()

                M = Mumbai[['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC']].mean()

                plt.subplots(figsize=(16, 10))
                plt.xlabel('Quarter', fontsize=15)
                plt.ylabel('Quarterly Rainfall (in mm)', fontsize=15)
                plt.title('Quarterly Rainfall in Tamilnadu,Delhi and Mumbai', fontsize=20)
                X = np.arange(11)
                bar1 = plt.bar(X + 0.00, T, color='lightgreen', width=0.25)
                bar2 = plt.bar(X + 0.25, D, color='violet', width=0.25)
                bar3 = plt.bar(X + 0.50, M, color='orange', width=0.25)

                plt.legend((bar1, bar2, bar3), ('Tamilnadu', 'Delhi', 'Mumbai'))
                plt.grid()
                plt.xticks(X + 0.25, ['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC'])
                plt.show()
            else:
                print("No Data Found")
        elif inp2 == "temp" or inp2 == "temperature":
            if inp3 == "bar" or inp3 == "barchar":
                print("No Data Found")
            else:
                print("No Data Found")
# Out:
# please Enter 'Yearly' or 'Monthly' month
# What type of data you want about the Weather - 'Rain' or 'Temperature' rain
# What Type of Graph you Want - 'Line' or 'Barchart' l
# No Data Found

# %%
    inp1 = input("please Enter 'Yearly' or 'Monthly' ")
    inp1.lower()
    inp2 = input("What type of data you want about the Weather - 'Rain' or 'Temperature' ")
    inp2.lower()
    inp3 = input("What Type of Graph you Want - 'Line' or 'Barchart' ")
    inp3.lower()
    if inp1 == "year" or inp1 == "yearly":
        if inp2 == "rain" or inp2 == "rainfall":
            if inp3 == "bar" or inp3 == "barchart":

                data[['SUBDIVISION', 'ANNUAL']].sort_values(by='ANNUAL', ascending=False).head(20)



                # Average monthly rainfall in India
                ax = data[['Jan-Feb', 'Mar-May', 'Jun-Sep', 'Oct-Dec']].mean().plot.bar(width=0.5, linewidth=2,
                                                                                        figsize=(16, 10))
                plt.xlabel('Quarter', fontsize=15)
                plt.ylabel('Quarterly Rainfall (in mm)', fontsize=15)
                plt.title('Quarterly Rainfall in India', fontsize=20)
                plt.legend(['Subdivisions'])
                ax.tick_params(labelsize=15)
                plt.grid()
                plt.show()



                # Getting rainfall data for Tamilnadu
                Tamilnadu = data.loc[((data['SUBDIVISION'] == 'TAMIL NADU'))]



                # Average monthly rainfall in Tamilnadu
                TM = Tamilnadu[['Jan-Feb', 'Mar-May', 'Jun-Sep', 'Oct-Dec']].mean().plot.bar(width=0.5, linewidth=2,
                                                                                             figsize=(16, 10),
                                                                                             color='lightgreen')
                plt.xlabel('Quarter', fontsize=15)
                plt.ylabel('Quarterly Rainfall (in mm)', fontsize=15)
                plt.title('Quarterly Rainfall in Tamilnadu', fontsize=20)
                plt.legend(['Tamilnadu'])
                TM.tick_params(labelsize=15)
                plt.grid()
                plt.show()



                print('Average annual rainfall received by Tamilnadu = ', int(Tamilnadu['ANNUAL'].mean()), 'mm')
                a = Tamilnadu[Tamilnadu['YEAR'] == 1917]

                # Getting rainfall data for Delhi
                Delhi = data.loc[(data['SUBDIVISION'] == 'DELHI')]



                # Average monthly rainfall in Arunachal Pradesh
                DM = Delhi[['Jan-Feb', 'Mar-May', 'Jun-Sep', 'Oct-Dec']].mean().plot.bar(width=0.5, linewidth=2,
                                                                                         figsize=(16, 10),
                                                                                         color="violet")
                plt.xlabel('Quarter', fontsize=15)
                plt.ylabel('Quarterly Rainfall (in mm)', fontsize=15)
                plt.title('Quarterly Rainfall in Delhi', fontsize=20)
                plt.legend(['Delhi'])
                DM.tick_params(labelsize=15)
                plt.grid()
                plt.show()



                print('Average annual rainfall received by Arunachal Pradesh = ', int(Delhi['ANNUAL'].mean()), 'mm')
                a = Delhi[Delhi['YEAR'] == 1948]

                # Getting rainfall data for Mumbai
                Mumbai = data.loc[(data['SUBDIVISION'] == 'MUMBAI')]



                # Average monthly rainfall in mumbai
                MM = Mumbai[['Jan-Feb', 'Mar-May', 'Jun-Sep', 'Oct-Dec']].mean().plot.bar(width=0.5, linewidth=2,
                                                                                          figsize=(16, 10),
                                                                                          color="orange")
                plt.xlabel('Quarter', fontsize=15)
                plt.ylabel('Quarterly Rainfall (in mm)', fontsize=15)
                plt.title('Quarterly Rainfall in Mumbai', fontsize=20)
                plt.legend(['Mumbai'])
                MM.tick_params(labelsize=15)
                plt.grid()
                plt.show()



                # Average monthly rainfall in t,M,D

                DM = Delhi[['Jan-Feb', 'Mar-May', 'Jun-Sep', 'Oct-Dec']].mean()

                TM = Tamilnadu[['Jan-Feb', 'Mar-May', 'Jun-Sep', 'Oct-Dec']].mean()
                MM = Mumbai[['Jan-Feb', 'Mar-May', 'Jun-Sep', 'Oct-Dec']].mean()

                plt.subplots(figsize=(16, 10))
                plt.xlabel('Quarter', fontsize=15)
                plt.ylabel('Quarterly Rainfall (in mm)', fontsize=15)
                plt.title('Quarterly Rainfall in Tamilnadu,Delhi and Mumbai', fontsize=20)
                X = np.arange(4)
                bar1 = plt.bar(X + 0.00, TM, color='lightgreen', width=0.25)
                bar2 = plt.bar(X + 0.25, DM, color='violet', width=0.25)
                bar3 = plt.bar(X + 0.50, MM, color='orange', width=0.25)

                plt.legend((bar1, bar2, bar3), ('Tamilnadu', 'Delhi', 'Mumbai'))
                plt.grid()
                plt.xticks(X + 0.25, ['Jan-Feb', 'Mar-May', 'Jun-Sep', 'Oct-Dec'])
                plt.show()




            else:
                
                # Visualizing annual rainfall over the years(1901-2015) in India
                ax = data.groupby("YEAR").mean()['ANNUAL'].plot(ylim=(1000, 2000), color='r', marker='o', linestyle='-',linewidth=2, figsize=(12, 10));
                plt.xlabel('Year', fontsize=20)
                plt.ylabel('Annual Rainfall (in mm)', fontsize=20)
                plt.title('Annual Rainfall from Year 1901 to 2015 in India', fontsize=25)
                plt.legend(['India'])
                ax.tick_params(labelsize=15)
                plt.grid()
                plt.show()
                

                # Visualizing annual rainfall over the years(1901-2015) in Tamilnadu
                TY = Tamilnadu.groupby("YEAR").mean()['ANNUAL'].plot(ylim=(50, 1500), color='green', marker='o',
                                                                     linestyle='-', linewidth=2, figsize=(12, 10));
                plt.xlabel('Year', fontsize=20)
                plt.ylabel('Tamilnadu Annual Rainfall (in mm)', fontsize=20)
                plt.title('Tamilnadu Annual Rainfall from Year 1901 to 2015', fontsize=25)
                plt.legend(['Tamilnadu'])
                TY.tick_params(labelsize=15)
                plt.grid()
                plt.show()

                # Visualizing annual rainfall over the years(1901-2015) in delhi
                DY = Delhi.groupby("YEAR").mean()['ANNUAL'].plot(ylim=(50, 6500), color='violet', marker='o',
                                                                 linestyle='-', linewidth=2, figsize=(12, 10));
                plt.xlabel('Year', fontsize=20)
                plt.ylabel('Delhi Annual Rainfall (in mm)', fontsize=20)
                plt.title('Delhi Annual Rainfall from Year 1901 to 2015', fontsize=25)
                plt.legend(['Delhi'])
                DY.tick_params(labelsize=15)
                plt.grid()
                plt.show()

                # Visualizing annual rainfall over the years(1901-2015) in mumbai
                MY = Mumbai.groupby("YEAR").mean()['ANNUAL'].plot(ylim=(1500, 6500), color='orange', marker='o',
                                                                  linestyle='-', linewidth=2, figsize=(12, 10));
                plt.xlabel('Year', fontsize=20)
                plt.ylabel('Mumbai Annual Rainfall (in mm)', fontsize=20)
                plt.title('Mumbai Annual Rainfall from Year 1901 to 2015', fontsize=25)
                plt.legend(['Mumbai'])
                ax.tick_params(labelsize=15)
                plt.grid()
                plt.show()

                # Visualizing annual rainfall over the years(1901-2015) in t,m,d
                TY = Tamilnadu.groupby("YEAR").mean()['ANNUAL'].plot(ylim=(50, 7000), color='green', marker='o',
                                                                     linestyle='-', linewidth=2, figsize=(12, 10));
                DY = Delhi.groupby("YEAR").mean()['ANNUAL'].plot(ylim=(50, 7000), color='violet', marker='o',
                                                                 linestyle='-', linewidth=2, figsize=(12, 10));

                MY = Mumbai.groupby("YEAR").mean()['ANNUAL'].plot(ylim=(50, 7000), color='orange', marker='o',
                                                                  linestyle='-', linewidth=2, figsize=(12, 10));
                plt.xlabel('Year', fontsize=20)
                plt.ylabel('T,D,and M Annual Rainfall (in mm)', fontsize=20)
                plt.title(' T,D,and M Annual Rainfall from Year 1901 to 2015', fontsize=25)
                plt.legend(['Tamilnadu', 'Delhi', 'Mumbai'])
                TY.tick_params(labelsize=15)
                DY.tick_params(labelsize=15)
                MY.tick_params(labelsize=15)
                plt.grid()
                plt.show()
                
                 # Visualizing annual rainfall over the years(1901-2015) in India
                ax = data.groupby("YEAR").mean()['ANNUAL'].plot(ylim=(1000, 2000), color='r', linestyle='-',linewidth=2, figsize=(12, 10));
                plt.xlabel('Year', fontsize=20)
                plt.ylabel('Annual Rainfall (in mm)', fontsize=20)
                plt.title('Annual Rainfall from Year 1901 to 2015 in India', fontsize=25)
                plt.legend(['India'])
                ax.tick_params(labelsize=15)
                plt.grid()
                plt.show()
                

                # Visualizing annual rainfall over the years(1901-2015) in Tamilnadu
                TY = Tamilnadu.groupby("YEAR").mean()['ANNUAL'].plot(ylim=(50, 1500), color='green',
                                                                     linestyle='-', linewidth=2, figsize=(12, 10));
                plt.xlabel('Year', fontsize=20)
                plt.ylabel('Tamilnadu Annual Rainfall (in mm)', fontsize=20)
                plt.title('Tamilnadu Annual Rainfall from Year 1901 to 2015', fontsize=25)
                plt.legend(['Tamilnadu'])
                TY.tick_params(labelsize=15)
                plt.grid()
                plt.show()

                # Visualizing annual rainfall over the years(1901-2015) in delhi
                DY = Delhi.groupby("YEAR").mean()['ANNUAL'].plot(ylim=(50, 6500), color='violet',
                                                                 linestyle='-', linewidth=2, figsize=(12, 10));
                plt.xlabel('Year', fontsize=20)
                plt.ylabel('Delhi Annual Rainfall (in mm)', fontsize=20)
                plt.title('Delhi Annual Rainfall from Year 1901 to 2015', fontsize=25)
                plt.legend(['Delhi'])
                DY.tick_params(labelsize=15)
                plt.grid()
                plt.show()

                # Visualizing annual rainfall over the years(1901-2015) in mumbai
                MY = Mumbai.groupby("YEAR").mean()['ANNUAL'].plot(ylim=(1500, 6500), color='orange',
                                                                  linestyle='-', linewidth=2, figsize=(12, 10));
                plt.xlabel('Year', fontsize=20)
                plt.ylabel('Mumbai Annual Rainfall (in mm)', fontsize=20)
                plt.title('Mumbai Annual Rainfall from Year 1901 to 2015', fontsize=25)
                plt.legend(['Mumbai'])
                ax.tick_params(labelsize=15)
                plt.grid()
                plt.show()

                # Visualizing annual rainfall over the years(1901-2015) in t,d,m
                TY = Tamilnadu.groupby("YEAR").mean()['ANNUAL'].plot(ylim=(50, 7000), color='green',
                                                                     linestyle='-', linewidth=2, figsize=(12, 10));
                DY = Delhi.groupby("YEAR").mean()['ANNUAL'].plot(ylim=(50, 7000), color='violet',
                                                                 linestyle='-', linewidth=2, figsize=(12, 10));

                MY = Mumbai.groupby("YEAR").mean()['ANNUAL'].plot(ylim=(50, 7000), color='orange',
                                                                  linestyle='-', linewidth=2, figsize=(12, 10));
                plt.xlabel('Year', fontsize=20)
                plt.ylabel('T,D,and M Annual Rainfall (in mm)', fontsize=20)
                plt.title('T,D,and M Annual Rainfall from Year 1901 to 2015', fontsize=25)
                plt.legend(['Tamilnadu', 'Delhi', 'Mumbai'])
                TY.tick_params(labelsize=15)
                DY.tick_params(labelsize=15)
                MY.tick_params(labelsize=15)
                plt.grid()
                plt.show()
                
                tempdata_selected = data[data["SUBDIVISION"].isin(["MUMBAI", "DELHI", "TAMIL NADU"])]
                tr_avg_temps = tempdata_selected[tempdata_selected["SUBDIVISION"]=="MUMBAI"]["ANNUAL"]
                br_avg_temps = tempdata_selected[tempdata_selected["SUBDIVISION"]=="DELHI"]["ANNUAL"]
                us_avg_temps = tempdata_selected[tempdata_selected["SUBDIVISION"]=="TAMIL NADU"]["ANNUAL"]
                plt.xlabel('Year', fontsize=10)
                plt.ylabel('T,D,and M Annual Rainfall (in mm)', fontsize=10)
                plt.title('T,D,and M Annual Rainfall from Year 1901 to 2015', fontsize=10)
                plt.legend(['Tamilnadu', 'Delhi', 'Mumbai'])
                sns.distplot(tr_avg_temps)
                sns.distplot(us_avg_temps)
                sns.distplot(br_avg_temps)
                plt.legend(['Tamilnadu', 'Delhi', 'Mumbai'])
                plt.show()

        elif inp2 == "temp" or inp2 == "temperature":
            if inp3 == "bar" or inp3 == "barchar":
                T = tempdata_selected[tempdata_selected["Country"] == cdata[2]]["AverageTemperature"]
                D = tempdata_selected[tempdata_selected["Country"] == cdata[1]]["AverageTemperature"]
                M = tempdata_selected[tempdata_selected["Country"] == cdata[0]]["AverageTemperature"]

                plt.subplots(figsize=(16, 10))
                plt.xlabel('Quarter', fontsize=15)
                plt.ylabel('Quarterly Rainfall (in mm)', fontsize=15)
                plt.title('Quarterly Rainfall in Tamilnadu,Delhi and Mumbai', fontsize=20)
                X = np.arange(6)
                bar1 = plt.bar(0.00, T, color='g', width=0.25)
                bar2 = plt.bar(0.25, D, color='b', width=0.25)
                bar3 = plt.bar(0.50, M, color='orange', width=0.25)

                plt.legend((bar1, bar2, bar3), ('Tamilnadu', 'Delhi', 'Mumbai'))
                plt.grid()
                # plt.xticks(X+0.25,['1900','1920','1940','1960','1980','2000'])
                plt.show()
            else:
                sns.distplot(tr_avg_temps)
                sns.distplot(us_avg_temps)
                sns.distplot(br_avg_temps)

                cdata = tempdata_selected["Country"].unique()
                for c in cdata:
                    sns.distplot(tempdata_selected[tempdata_selected["Country"] == c]["AverageTemperature"])

                sns.set_style("whitegrid")
                plt.legend(['Mumbai','Delhi','Tamilnadu'])
                plt.figure(figsize=(15, 5))

                for c in cdata:
                    sns.distplot(tempdata_selected[tempdata_selected["Country"] == c]["AverageTemperature"])

                plt.legend(cdata)

                sns.set_style("whitegrid")
                plt.figure(figsize=(15, 5))
                color = ["green", "blue", "orange"]

                for color, c in zip(color, cdata):
                    sns.distplot(tempdata_selected[tempdata_selected["Country"] == c]["AverageTemperature"])
                    cmean = tempdata_selected[tempdata_selected["Country"] == c]["AverageTemperature"].mean()
                    plt.vlines(cmean, 0, 0.16, color=color)

                plt.legend(cdata)

                tempdata_selected.columns[1:3]

                colv = tempdata_selected.columns[1:3]
                cdata = tempdata_selected["Country"].unique()
                plt.figure(figsize=(15, 5))

                for col in colv:
                    plt.figure(figsize=(15, 5))
                    for c in cdata:
                        sns.distplot(tempdata_selected[tempdata_selected["Country"] == c][col])
                    plt.legend(['Mumbai','Delhi','Tamilnadu'])
                    plt.show()

                trData = tempdata_selected[(tempdata_selected["Country"] == "Mumbai") & (tempdata_selected["dt"] > "01.01.1900")]
                

                trData_mean = trData.groupby(trData["dt"].dt.to_period("Y")).mean()
                trData_mean = trData_mean.reset_index()
                
                trData_mean["dt"] = trData_mean["dt"].astype("string").astype("datetime64")
                plt.figure(figsize=(15, 5))

                sns.lineplot(x="dt", y="AverageTemperature", data=trData_mean,color='b')
                plt.legend(['Mumbai'])
                
                trData = tempdata_selected[(tempdata_selected["Country"] == "Delhi") & (tempdata_selected["dt"] > "01.01.1900")]
                

                trData_mean = trData.groupby(trData["dt"].dt.to_period("Y")).mean()
                trData_mean = trData_mean.reset_index()
                
                trData_mean["dt"] = trData_mean["dt"].astype("string").astype("datetime64")
                plt.figure(figsize=(15, 5))

                sns.lineplot(x="dt", y="AverageTemperature", data=trData_mean,color='orange')
                plt.legend(['Delhi'])
                
                trData = tempdata_selected[(tempdata_selected["Country"] == "Tamilnadu") & (tempdata_selected["dt"] > "01.01.1900")]
                

                trData_mean = trData.groupby(trData["dt"].dt.to_period("Y")).mean()
                trData_mean = trData_mean.reset_index()
                
                trData_mean["dt"] = trData_mean["dt"].astype("string").astype("datetime64")
                plt.figure(figsize=(15, 5))

                sns.lineplot(x="dt", y="AverageTemperature", data=trData_mean,color='g')
                plt.legend(['Tamilnadu'])
                
                data_1900 = tempdata_selected[tempdata_selected["dt"] > "01.01.1900"]
                
                data_means = data_1900.groupby(["Country", data_1900["dt"].dt.to_period("Y")]).mean()
                data_means = data_means.reset_index()
                data_means["dt"] = data_means["dt"].astype("string").astype("datetime64")
                
                for column in data_means.columns[2:4]:
                    plt.figure(figsize=(15, 5))

                    for c in data_means["Country"].unique():
                        data = data_means[data_means["Country"] == c]
                        sns.lineplot(x="dt", y=col, data=data)
                    plt.legend(['Mumbai','Delhi','Tamilnadu'])

    elif inp1 == "month" or inp1 == "monthly":

        if inp2 == "rain" or inp2 == "rainfall":

            if inp3 == "bar" or inp3 == "barchart":
                # Average monthly rainfall in India
                ax = data[['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC']].mean()
                plt.subplots(figsize=(16, 10))
                plt.xlabel('Month', fontsize=30)
                plt.ylabel('Monthly Rainfall (in mm)', fontsize=30)
                plt.title('Monthly Rainfall in Subdivisions of India', fontsize=25)
                
               
                X = np.arange(11)
                bar1 = plt.bar(X + 0.00, ax, color='b', width=0.25)
                plt.legend(['Subdivisions'])
                plt.grid()
                plt.xticks(X + 0.25, ['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC'])
                plt.show()

                # Average monthly rainfall in Tamilnadu
                T = Tamilnadu[['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC']].mean()
                plt.subplots(figsize=(16, 10))
                plt.xlabel('Month', fontsize=30)
                plt.ylabel('Monthly Rainfall (in mm)', fontsize=30)
                plt.title('Monthly Rainfall in Tamilnadu', fontsize=25)
                
                X = np.arange(11)
                plt.bar(X + 0.00, T, color='lightgreen', width=0.25)
                

                plt.legend(['Tamilnadu'])
                plt.grid()
                plt.xticks(X + 0.25, ['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC'])
                plt.show()

                # Average monthly rainfall in Delhi
                D = Delhi[['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC']].mean()
                plt.subplots(figsize=(16, 10))
                plt.xlabel('Month', fontsize=30)
                plt.ylabel('Monthly Rainfall (in mm)', fontsize=30)
                plt.title('Monthly Rainfall in Delhi', fontsize=25)
                
                X = np.arange(11)
                
                bar2 = plt.bar(X + 0.25, D, color='violet', width=0.25)
                

                plt.legend(['Delhi'])
                plt.grid()
                plt.xticks(X + 0.25, ['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC'])
                plt.show()
                
                

                # Average monthly rainfall in Mumbai
                M = Mumbai[['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC']].mean()
                plt.subplots(figsize=(16, 10))
                plt.xlabel('Month', fontsize=30)
                plt.ylabel('Monthly Rainfall (in mm)', fontsize=30)
                plt.title('Monthly Rainfall in Mumbai', fontsize=25)
                
                X = np.arange(11)
                
                bar3 = plt.bar(X + 0.50, M, color='orange', width=0.25)

                plt.legend(['Mumbai'])
                plt.grid()
                plt.xticks(X + 0.25, ['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC'])
                plt.show()


                # Average monthly rainfall in Tamilnadu
                T = Tamilnadu[['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC']].mean()

                D = Delhi[['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC']].mean()

                M = Mumbai[['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC']].mean()

                plt.subplots(figsize=(16, 10))
                plt.xlabel('Quarter', fontsize=15)
                plt.ylabel('Quarterly Rainfall (in mm)', fontsize=15)
                plt.title('Quarterly Rainfall in Tamilnadu,Delhi and Mumbai', fontsize=20)
                X = np.arange(11)
                bar1 = plt.bar(X + 0.00, T, color='lightgreen', width=0.25)
                bar2 = plt.bar(X + 0.25, D, color='violet', width=0.25)
                bar3 = plt.bar(X + 0.50, M, color='orange', width=0.25)

                plt.legend((bar1, bar2, bar3), ('Tamilnadu', 'Delhi', 'Mumbai'))
                plt.grid()
                plt.xticks(X + 0.25, ['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC'])
                plt.show()
            else:
                print("No Data Found")
        elif inp2 == "temp" or inp2 == "temperature":
            if inp3 == "bar" or inp3 == "barchar":
                print("No Data Found")
            else:
                print("No Data Found")
# Out:
# please Enter 'Yearly' or 'Monthly' month
# What type of data you want about the Weather - 'Rain' or 'Temperature' temp
# What Type of Graph you Want - 'Line' or 'Barchart' bar
# No Data Found

# %%
    inp1 = input("please Enter 'Yearly' or 'Monthly' ")
    inp1.lower()
    inp2 = input("What type of data you want about the Weather - 'Rain' or 'Temperature' ")
    inp2.lower()
    inp3 = input("What Type of Graph you Want - 'Line' or 'Barchart' ")
    inp3.lower()
    if inp1 == "year" or inp1 == "yearly":
        if inp2 == "rain" or inp2 == "rainfall":
            if inp3 == "bar" or inp3 == "barchart":

                data[['SUBDIVISION', 'ANNUAL']].sort_values(by='ANNUAL', ascending=False).head(20)



                # Average monthly rainfall in India
                ax = data[['Jan-Feb', 'Mar-May', 'Jun-Sep', 'Oct-Dec']].mean().plot.bar(width=0.5, linewidth=2,
                                                                                        figsize=(16, 10))
                plt.xlabel('Quarter', fontsize=15)
                plt.ylabel('Quarterly Rainfall (in mm)', fontsize=15)
                plt.title('Quarterly Rainfall in India', fontsize=20)
                plt.legend(['Subdivisions'])
                ax.tick_params(labelsize=15)
                plt.grid()
                plt.show()



                # Getting rainfall data for Tamilnadu
                Tamilnadu = data.loc[((data['SUBDIVISION'] == 'TAMIL NADU'))]



                # Average monthly rainfall in Tamilnadu
                TM = Tamilnadu[['Jan-Feb', 'Mar-May', 'Jun-Sep', 'Oct-Dec']].mean().plot.bar(width=0.5, linewidth=2,
                                                                                             figsize=(16, 10),
                                                                                             color='lightgreen')
                plt.xlabel('Quarter', fontsize=15)
                plt.ylabel('Quarterly Rainfall (in mm)', fontsize=15)
                plt.title('Quarterly Rainfall in Tamilnadu', fontsize=20)
                plt.legend(['Tamilnadu'])
                TM.tick_params(labelsize=15)
                plt.grid()
                plt.show()



                print('Average annual rainfall received by Tamilnadu = ', int(Tamilnadu['ANNUAL'].mean()), 'mm')
                a = Tamilnadu[Tamilnadu['YEAR'] == 1917]

                # Getting rainfall data for Delhi
                Delhi = data.loc[(data['SUBDIVISION'] == 'DELHI')]



                # Average monthly rainfall in Arunachal Pradesh
                DM = Delhi[['Jan-Feb', 'Mar-May', 'Jun-Sep', 'Oct-Dec']].mean().plot.bar(width=0.5, linewidth=2,
                                                                                         figsize=(16, 10),
                                                                                         color="violet")
                plt.xlabel('Quarter', fontsize=15)
                plt.ylabel('Quarterly Rainfall (in mm)', fontsize=15)
                plt.title('Quarterly Rainfall in Delhi', fontsize=20)
                plt.legend(['Delhi'])
                DM.tick_params(labelsize=15)
                plt.grid()
                plt.show()



                print('Average annual rainfall received by Arunachal Pradesh = ', int(Delhi['ANNUAL'].mean()), 'mm')
                a = Delhi[Delhi['YEAR'] == 1948]

                # Getting rainfall data for Mumbai
                Mumbai = data.loc[(data['SUBDIVISION'] == 'MUMBAI')]



                # Average monthly rainfall in mumbai
                MM = Mumbai[['Jan-Feb', 'Mar-May', 'Jun-Sep', 'Oct-Dec']].mean().plot.bar(width=0.5, linewidth=2,
                                                                                          figsize=(16, 10),
                                                                                          color="orange")
                plt.xlabel('Quarter', fontsize=15)
                plt.ylabel('Quarterly Rainfall (in mm)', fontsize=15)
                plt.title('Quarterly Rainfall in Mumbai', fontsize=20)
                plt.legend(['Mumbai'])
                MM.tick_params(labelsize=15)
                plt.grid()
                plt.show()



                # Average monthly rainfall in t,M,D

                DM = Delhi[['Jan-Feb', 'Mar-May', 'Jun-Sep', 'Oct-Dec']].mean()

                TM = Tamilnadu[['Jan-Feb', 'Mar-May', 'Jun-Sep', 'Oct-Dec']].mean()
                MM = Mumbai[['Jan-Feb', 'Mar-May', 'Jun-Sep', 'Oct-Dec']].mean()

                plt.subplots(figsize=(16, 10))
                plt.xlabel('Quarter', fontsize=15)
                plt.ylabel('Quarterly Rainfall (in mm)', fontsize=15)
                plt.title('Quarterly Rainfall in Tamilnadu,Delhi and Mumbai', fontsize=20)
                X = np.arange(4)
                bar1 = plt.bar(X + 0.00, TM, color='lightgreen', width=0.25)
                bar2 = plt.bar(X + 0.25, DM, color='violet', width=0.25)
                bar3 = plt.bar(X + 0.50, MM, color='orange', width=0.25)

                plt.legend((bar1, bar2, bar3), ('Tamilnadu', 'Delhi', 'Mumbai'))
                plt.grid()
                plt.xticks(X + 0.25, ['Jan-Feb', 'Mar-May', 'Jun-Sep', 'Oct-Dec'])
                plt.show()




            else:
                
                # Visualizing annual rainfall over the years(1901-2015) in India
                ax = data.groupby("YEAR").mean()['ANNUAL'].plot(ylim=(1000, 2000), color='r', marker='o', linestyle='-',linewidth=2, figsize=(12, 10));
                plt.xlabel('Year', fontsize=20)
                plt.ylabel('Annual Rainfall (in mm)', fontsize=20)
                plt.title('Annual Rainfall from Year 1901 to 2015 in India', fontsize=25)
                plt.legend(['India'])
                ax.tick_params(labelsize=15)
                plt.grid()
                plt.show()
                

                # Visualizing annual rainfall over the years(1901-2015) in Tamilnadu
                TY = Tamilnadu.groupby("YEAR").mean()['ANNUAL'].plot(ylim=(50, 1500), color='green', marker='o',
                                                                     linestyle='-', linewidth=2, figsize=(12, 10));
                plt.xlabel('Year', fontsize=20)
                plt.ylabel('Tamilnadu Annual Rainfall (in mm)', fontsize=20)
                plt.title('Tamilnadu Annual Rainfall from Year 1901 to 2015', fontsize=25)
                plt.legend(['Tamilnadu'])
                TY.tick_params(labelsize=15)
                plt.grid()
                plt.show()

                # Visualizing annual rainfall over the years(1901-2015) in delhi
                DY = Delhi.groupby("YEAR").mean()['ANNUAL'].plot(ylim=(50, 6500), color='violet', marker='o',
                                                                 linestyle='-', linewidth=2, figsize=(12, 10));
                plt.xlabel('Year', fontsize=20)
                plt.ylabel('Delhi Annual Rainfall (in mm)', fontsize=20)
                plt.title('Delhi Annual Rainfall from Year 1901 to 2015', fontsize=25)
                plt.legend(['Delhi'])
                DY.tick_params(labelsize=15)
                plt.grid()
                plt.show()

                # Visualizing annual rainfall over the years(1901-2015) in mumbai
                MY = Mumbai.groupby("YEAR").mean()['ANNUAL'].plot(ylim=(1500, 6500), color='orange', marker='o',
                                                                  linestyle='-', linewidth=2, figsize=(12, 10));
                plt.xlabel('Year', fontsize=20)
                plt.ylabel('Mumbai Annual Rainfall (in mm)', fontsize=20)
                plt.title('Mumbai Annual Rainfall from Year 1901 to 2015', fontsize=25)
                plt.legend(['Mumbai'])
                ax.tick_params(labelsize=15)
                plt.grid()
                plt.show()

                # Visualizing annual rainfall over the years(1901-2015) in t,m,d
                TY = Tamilnadu.groupby("YEAR").mean()['ANNUAL'].plot(ylim=(50, 7000), color='green', marker='o',
                                                                     linestyle='-', linewidth=2, figsize=(12, 10));
                DY = Delhi.groupby("YEAR").mean()['ANNUAL'].plot(ylim=(50, 7000), color='violet', marker='o',
                                                                 linestyle='-', linewidth=2, figsize=(12, 10));

                MY = Mumbai.groupby("YEAR").mean()['ANNUAL'].plot(ylim=(50, 7000), color='orange', marker='o',
                                                                  linestyle='-', linewidth=2, figsize=(12, 10));
                plt.xlabel('Year', fontsize=20)
                plt.ylabel('T,D,and M Annual Rainfall (in mm)', fontsize=20)
                plt.title(' T,D,and M Annual Rainfall from Year 1901 to 2015', fontsize=25)
                plt.legend(['Tamilnadu', 'Delhi', 'Mumbai'])
                TY.tick_params(labelsize=15)
                DY.tick_params(labelsize=15)
                MY.tick_params(labelsize=15)
                plt.grid()
                plt.show()
                
                 # Visualizing annual rainfall over the years(1901-2015) in India
                ax = data.groupby("YEAR").mean()['ANNUAL'].plot(ylim=(1000, 2000), color='r', linestyle='-',linewidth=2, figsize=(12, 10));
                plt.xlabel('Year', fontsize=20)
                plt.ylabel('Annual Rainfall (in mm)', fontsize=20)
                plt.title('Annual Rainfall from Year 1901 to 2015 in India', fontsize=25)
                plt.legend(['India'])
                ax.tick_params(labelsize=15)
                plt.grid()
                plt.show()
                

                # Visualizing annual rainfall over the years(1901-2015) in Tamilnadu
                TY = Tamilnadu.groupby("YEAR").mean()['ANNUAL'].plot(ylim=(50, 1500), color='green',
                                                                     linestyle='-', linewidth=2, figsize=(12, 10));
                plt.xlabel('Year', fontsize=20)
                plt.ylabel('Tamilnadu Annual Rainfall (in mm)', fontsize=20)
                plt.title('Tamilnadu Annual Rainfall from Year 1901 to 2015', fontsize=25)
                plt.legend(['Tamilnadu'])
                TY.tick_params(labelsize=15)
                plt.grid()
                plt.show()

                # Visualizing annual rainfall over the years(1901-2015) in delhi
                DY = Delhi.groupby("YEAR").mean()['ANNUAL'].plot(ylim=(50, 6500), color='violet',
                                                                 linestyle='-', linewidth=2, figsize=(12, 10));
                plt.xlabel('Year', fontsize=20)
                plt.ylabel('Delhi Annual Rainfall (in mm)', fontsize=20)
                plt.title('Delhi Annual Rainfall from Year 1901 to 2015', fontsize=25)
                plt.legend(['Delhi'])
                DY.tick_params(labelsize=15)
                plt.grid()
                plt.show()

                # Visualizing annual rainfall over the years(1901-2015) in mumbai
                MY = Mumbai.groupby("YEAR").mean()['ANNUAL'].plot(ylim=(1500, 6500), color='orange',
                                                                  linestyle='-', linewidth=2, figsize=(12, 10));
                plt.xlabel('Year', fontsize=20)
                plt.ylabel('Mumbai Annual Rainfall (in mm)', fontsize=20)
                plt.title('Mumbai Annual Rainfall from Year 1901 to 2015', fontsize=25)
                plt.legend(['Mumbai'])
                ax.tick_params(labelsize=15)
                plt.grid()
                plt.show()

                # Visualizing annual rainfall over the years(1901-2015) in t,d,m
                TY = Tamilnadu.groupby("YEAR").mean()['ANNUAL'].plot(ylim=(50, 7000), color='green',
                                                                     linestyle='-', linewidth=2, figsize=(12, 10));
                DY = Delhi.groupby("YEAR").mean()['ANNUAL'].plot(ylim=(50, 7000), color='violet',
                                                                 linestyle='-', linewidth=2, figsize=(12, 10));

                MY = Mumbai.groupby("YEAR").mean()['ANNUAL'].plot(ylim=(50, 7000), color='orange',
                                                                  linestyle='-', linewidth=2, figsize=(12, 10));
                plt.xlabel('Year', fontsize=20)
                plt.ylabel('T,D,and M Annual Rainfall (in mm)', fontsize=20)
                plt.title('T,D,and M Annual Rainfall from Year 1901 to 2015', fontsize=25)
                plt.legend(['Tamilnadu', 'Delhi', 'Mumbai'])
                TY.tick_params(labelsize=15)
                DY.tick_params(labelsize=15)
                MY.tick_params(labelsize=15)
                plt.grid()
                plt.show()
                
                tempdata_selected = data[data["SUBDIVISION"].isin(["MUMBAI", "DELHI", "TAMIL NADU"])]
                tr_avg_temps = tempdata_selected[tempdata_selected["SUBDIVISION"]=="MUMBAI"]["ANNUAL"]
                br_avg_temps = tempdata_selected[tempdata_selected["SUBDIVISION"]=="DELHI"]["ANNUAL"]
                us_avg_temps = tempdata_selected[tempdata_selected["SUBDIVISION"]=="TAMIL NADU"]["ANNUAL"]
                plt.xlabel('Year', fontsize=10)
                plt.ylabel('T,D,and M Annual Rainfall (in mm)', fontsize=10)
                plt.title('T,D,and M Annual Rainfall from Year 1901 to 2015', fontsize=10)
                plt.legend(['Tamilnadu', 'Delhi', 'Mumbai'])
                sns.distplot(tr_avg_temps)
                sns.distplot(us_avg_temps)
                sns.distplot(br_avg_temps)
                plt.legend(['Tamilnadu', 'Delhi', 'Mumbai'])
                plt.show()

        elif inp2 == "temp" or inp2 == "temperature":
            if inp3 == "bar" or inp3 == "barchar":
                T = tempdata_selected[tempdata_selected["Country"] == cdata[2]]["AverageTemperature"]
                D = tempdata_selected[tempdata_selected["Country"] == cdata[1]]["AverageTemperature"]
                M = tempdata_selected[tempdata_selected["Country"] == cdata[0]]["AverageTemperature"]

                plt.subplots(figsize=(16, 10))
                plt.xlabel('Quarter', fontsize=15)
                plt.ylabel('Quarterly Rainfall (in mm)', fontsize=15)
                plt.title('Quarterly Rainfall in Tamilnadu,Delhi and Mumbai', fontsize=20)
                X = np.arange(6)
                bar1 = plt.bar(0.00, T, color='g', width=0.25)
                bar2 = plt.bar(0.25, D, color='b', width=0.25)
                bar3 = plt.bar(0.50, M, color='orange', width=0.25)

                plt.legend((bar1, bar2, bar3), ('Tamilnadu', 'Delhi', 'Mumbai'))
                plt.grid()
                # plt.xticks(X+0.25,['1900','1920','1940','1960','1980','2000'])
                plt.show()
            else:
                sns.distplot(tr_avg_temps)
                sns.distplot(us_avg_temps)
                sns.distplot(br_avg_temps)

                cdata = tempdata_selected["Country"].unique()
                for c in cdata:
                    sns.distplot(tempdata_selected[tempdata_selected["Country"] == c]["AverageTemperature"])

                sns.set_style("whitegrid")
                plt.legend(['Mumbai','Delhi','Tamilnadu'])
                plt.figure(figsize=(15, 5))

                for c in cdata:
                    sns.distplot(tempdata_selected[tempdata_selected["Country"] == c]["AverageTemperature"])

                plt.legend(cdata)

                sns.set_style("whitegrid")
                plt.figure(figsize=(15, 5))
                color = ["green", "blue", "orange"]

                for color, c in zip(color, cdata):
                    sns.distplot(tempdata_selected[tempdata_selected["Country"] == c]["AverageTemperature"])
                    cmean = tempdata_selected[tempdata_selected["Country"] == c]["AverageTemperature"].mean()
                    plt.vlines(cmean, 0, 0.16, color=color)

                plt.legend(cdata)

                tempdata_selected.columns[1:3]

                colv = tempdata_selected.columns[1:3]
                cdata = tempdata_selected["Country"].unique()
                plt.figure(figsize=(15, 5))

                for col in colv:
                    plt.figure(figsize=(15, 5))
                    for c in cdata:
                        sns.distplot(tempdata_selected[tempdata_selected["Country"] == c][col])
                    plt.legend(['Mumbai','Delhi','Tamilnadu'])
                    plt.show()

                trData = tempdata_selected[(tempdata_selected["Country"] == "Mumbai") & (tempdata_selected["dt"] > "01.01.1900")]
                

                trData_mean = trData.groupby(trData["dt"].dt.to_period("Y")).mean()
                trData_mean = trData_mean.reset_index()
                
                trData_mean["dt"] = trData_mean["dt"].astype("string").astype("datetime64")
                plt.figure(figsize=(15, 5))

                sns.lineplot(x="dt", y="AverageTemperature", data=trData_mean,color='b')
                plt.legend(['Mumbai'])
                
                trData = tempdata_selected[(tempdata_selected["Country"] == "Delhi") & (tempdata_selected["dt"] > "01.01.1900")]
                

                trData_mean = trData.groupby(trData["dt"].dt.to_period("Y")).mean()
                trData_mean = trData_mean.reset_index()
                
                trData_mean["dt"] = trData_mean["dt"].astype("string").astype("datetime64")
                plt.figure(figsize=(15, 5))

                sns.lineplot(x="dt", y="AverageTemperature", data=trData_mean,color='orange')
                plt.legend(['Delhi'])
                
                trData = tempdata_selected[(tempdata_selected["Country"] == "Tamilnadu") & (tempdata_selected["dt"] > "01.01.1900")]
                

                trData_mean = trData.groupby(trData["dt"].dt.to_period("Y")).mean()
                trData_mean = trData_mean.reset_index()
                
                trData_mean["dt"] = trData_mean["dt"].astype("string").astype("datetime64")
                plt.figure(figsize=(15, 5))

                sns.lineplot(x="dt", y="AverageTemperature", data=trData_mean,color='g')
                plt.legend(['Tamilnadu'])
                
                data_1900 = tempdata_selected[tempdata_selected["dt"] > "01.01.1900"]
                
                data_means = data_1900.groupby(["Country", data_1900["dt"].dt.to_period("Y")]).mean()
                data_means = data_means.reset_index()
                data_means["dt"] = data_means["dt"].astype("string").astype("datetime64")
                
                for column in data_means.columns[2:4]:
                    plt.figure(figsize=(15, 5))

                    for c in data_means["Country"].unique():
                        data = data_means[data_means["Country"] == c]
                        sns.lineplot(x="dt", y=col, data=data)
                    plt.legend(['Mumbai','Delhi','Tamilnadu'])

    elif inp1 == "month" or inp1 == "monthly":

        if inp2 == "rain" or inp2 == "rainfall":

            if inp3 == "bar" or inp3 == "barchart":
                # Average monthly rainfall in India
                ax = data[['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC']].mean()
                plt.subplots(figsize=(16, 10))
                plt.xlabel('Month', fontsize=30)
                plt.ylabel('Monthly Rainfall (in mm)', fontsize=30)
                plt.title('Monthly Rainfall in Subdivisions of India', fontsize=25)
                
               
                X = np.arange(11)
                bar1 = plt.bar(X + 0.00, ax, color='b', width=0.25)
                plt.legend(['Subdivisions'])
                plt.grid()
                plt.xticks(X + 0.25, ['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC'])
                plt.show()

                # Average monthly rainfall in Tamilnadu
                T = Tamilnadu[['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC']].mean()
                plt.subplots(figsize=(16, 10))
                plt.xlabel('Month', fontsize=30)
                plt.ylabel('Monthly Rainfall (in mm)', fontsize=30)
                plt.title('Monthly Rainfall in Tamilnadu', fontsize=25)
                
                X = np.arange(11)
                plt.bar(X + 0.00, T, color='lightgreen', width=0.25)
                

                plt.legend(['Tamilnadu'])
                plt.grid()
                plt.xticks(X + 0.25, ['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC'])
                plt.show()

                # Average monthly rainfall in Delhi
                D = Delhi[['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC']].mean()
                plt.subplots(figsize=(16, 10))
                plt.xlabel('Month', fontsize=30)
                plt.ylabel('Monthly Rainfall (in mm)', fontsize=30)
                plt.title('Monthly Rainfall in Delhi', fontsize=25)
                
                X = np.arange(11)
                
                bar2 = plt.bar(X + 0.25, D, color='violet', width=0.25)
                

                plt.legend(['Delhi'])
                plt.grid()
                plt.xticks(X + 0.25, ['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC'])
                plt.show()
                
                

                # Average monthly rainfall in Mumbai
                M = Mumbai[['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC']].mean()
                plt.subplots(figsize=(16, 10))
                plt.xlabel('Month', fontsize=30)
                plt.ylabel('Monthly Rainfall (in mm)', fontsize=30)
                plt.title('Monthly Rainfall in Mumbai', fontsize=25)
                
                X = np.arange(11)
                
                bar3 = plt.bar(X + 0.50, M, color='orange', width=0.25)

                plt.legend(['Mumbai'])
                plt.grid()
                plt.xticks(X + 0.25, ['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC'])
                plt.show()


                # Average monthly rainfall in Tamilnadu
                T = Tamilnadu[['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC']].mean()

                D = Delhi[['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC']].mean()

                M = Mumbai[['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC']].mean()

                plt.subplots(figsize=(16, 10))
                plt.xlabel('Quarter', fontsize=15)
                plt.ylabel('Quarterly Rainfall (in mm)', fontsize=15)
                plt.title('Quarterly Rainfall in Tamilnadu,Delhi and Mumbai', fontsize=20)
                X = np.arange(11)
                bar1 = plt.bar(X + 0.00, T, color='lightgreen', width=0.25)
                bar2 = plt.bar(X + 0.25, D, color='violet', width=0.25)
                bar3 = plt.bar(X + 0.50, M, color='orange', width=0.25)

                plt.legend((bar1, bar2, bar3), ('Tamilnadu', 'Delhi', 'Mumbai'))
                plt.grid()
                plt.xticks(X + 0.25, ['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC'])
                plt.show()
            else:
                print("No Data Found")
        elif inp2 == "temp" or inp2 == "temperature":
            if inp3 == "bar" or inp3 == "barchar":
                print("No Data Found")
            else:
                print("No Data Found")
# Out:
# please Enter 'Yearly' or 'Monthly' month
# What type of data you want about the Weather - 'Rain' or 'Temperature' temp
# What Type of Graph you Want - 'Line' or 'Barchart' l
# No Data Found
